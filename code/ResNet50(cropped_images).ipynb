# %%
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# CELL 1 ── Install & verify GPU
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━

# !pip install -q tensorflow==2.15.0 scikit-learn matplotlib seaborn opencv-python-headless

import tensorflow as tf
from tensorflow.keras import mixed_precision
mixed_precision.set_global_policy("mixed_float16")

print("TensorFlow :", tf.__version__)
print("GPU        :", tf.config.list_physical_devices("GPU"))
print("Policy     :", mixed_precision.global_policy().name)


# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# CELL 2 ── Mount Drive & Configuration
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━

from google.colab import drive
drive.mount("/content/drive")

import os, math, warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
from pathlib import Path
from sklearn.metrics import (
    confusion_matrix, classification_report, roc_auc_score,
    roc_curve, f1_score, average_precision_score,
    precision_recall_curve, matthews_corrcoef
)
from tensorflow.keras import layers, Model, callbacks, optimizers, regularizers
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input

warnings.filterwarnings("ignore")
tf.get_logger().setLevel("ERROR")

# ── Paths ─────────────────────────────────────────────────────────────────
SPLIT_DIR = Path("/content/drive/MyDrive/Breast_cancer_dataset/cropped_split")
SAVE_DIR  = Path("/content/drive/MyDrive/Breast_cancer_dataset/model_output/resnet50")
SAVE_DIR.mkdir(parents=True, exist_ok=True)

TRAIN_DIR = SPLIT_DIR / "train"
VAL_DIR   = SPLIT_DIR / "val"
TEST_DIR  = SPLIT_DIR / "test"

# ── Settings ───────────────────────────────────────────────────────────────
MODEL_NAME      = "ResNet50"
IMG_SIZE        = 224
CHANNELS        = 3
BATCH_SIZE      = 32
PHASE1_EPOCHS   = 20
PHASE2_EPOCHS   = 30
PHASE1_LR       = 1e-3
PHASE2_LR       = 1e-5
UNFREEZE_LAYERS = 60
DROPOUT_RATE    = 0.5
L2_REG          = 1e-4
RANDOM_SEED     = 42
CUSTOM_HEAD     = {"gap","bn1","fc1","drop1","bn2","fc2","drop2","output"}

tf.random.set_seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)

print("=" * 65)
print(f"  Model      : {MODEL_NAME}")
print(f"  Input size : {IMG_SIZE}×{IMG_SIZE}×{CHANNELS}")
print(f"  Save dir   : {SAVE_DIR}")
print("=" * 65)


# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# CELL 3 ── Dataset inspection & class weights
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━

IMG_EXTS = (".jpg", ".jpeg", ".png")
stats = {}
for split in ["train", "val", "test"]:
    counts = {}
    for label in ["malignant", "benign"]:
        p = SPLIT_DIR / split / label
        counts[label] = len([f for f in p.iterdir()
                             if f.suffix.lower() in IMG_EXTS]) if p.exists() else 0
    stats[split] = counts

print(f"  {'Split':<8} {'Malignant':>10} {'Benign':>8} {'Total':>7}  Mal%")
print(f"  {'─'*42}")
for split, cnt in stats.items():
    mal = cnt["malignant"]; ben = cnt["benign"]; tot = mal + ben
    print(f"  {split:<8} {mal:>10,} {ben:>8,} {tot:>7,}  {mal/tot*100:.1f}%")

n_mal = stats["train"]["malignant"]
n_ben = stats["train"]["benign"]
n_tot = n_mal + n_ben
CLASS_WEIGHTS = {0: n_tot/(2*n_ben), 1: n_tot/(2*n_mal)}
print(f"\n  Class weights → benign:{CLASS_WEIGHTS[0]:.4f}  malignant:{CLASS_WEIGHTS[1]:.4f}")


# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# CELL 4 ── Preprocessing & augmentation
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━

def apply_clahe(img_np):
    img_u8 = img_np.astype(np.uint8)
    lab     = cv2.cvtColor(img_u8, cv2.COLOR_RGB2LAB)
    l, a, b = cv2.split(lab)
    clahe   = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    lab_eq  = cv2.merge([clahe.apply(l), a, b])
    return cv2.cvtColor(lab_eq, cv2.COLOR_LAB2RGB)

def preprocess_train(image_path, label):
    raw   = tf.io.read_file(image_path)
    image = tf.image.decode_jpeg(raw, channels=CHANNELS)
    image = tf.image.resize(image, [IMG_SIZE, IMG_SIZE])
    image = tf.cast(image, tf.uint8)
    image = tf.py_function(lambda x: apply_clahe(x.numpy()), [image], tf.uint8)
    image.set_shape([IMG_SIZE, IMG_SIZE, 3])
    image = tf.cast(image, tf.float32)
    image = preprocess_input(image)
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_flip_up_down(image)
    crop_pct  = tf.random.uniform([], 0.85, 1.0)
    crop_size = tf.cast(tf.cast(IMG_SIZE, tf.float32) * crop_pct, tf.int32)
    image = tf.image.random_crop(image, [crop_size, crop_size, 3])
    image = tf.image.resize(image, [IMG_SIZE, IMG_SIZE])
    image = tf.image.random_brightness(image, max_delta=0.2)
    image = tf.image.random_contrast(image, lower=0.8, upper=1.2)
    noise = tf.random.normal(tf.shape(image), mean=0.0, stddev=0.02)
    image = tf.clip_by_value(image + noise, -3.0, 3.0)
    return image, tf.cast(label, tf.float32)

def preprocess_val(image_path, label):
    raw   = tf.io.read_file(image_path)
    image = tf.image.decode_jpeg(raw, channels=CHANNELS)
    image = tf.image.resize(image, [IMG_SIZE, IMG_SIZE])
    image = tf.cast(image, tf.uint8)
    image = tf.py_function(lambda x: apply_clahe(x.numpy()), [image], tf.uint8)
    image.set_shape([IMG_SIZE, IMG_SIZE, 3])
    image = tf.cast(image, tf.float32)
    image = preprocess_input(image)
    return image, tf.cast(label, tf.float32)


# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# CELL 5 ── tf.data pipelines
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━

def collect(split_path):
    paths, labels = [], []
    for name, val in [("malignant",1),("benign",0)]:
        folder = split_path / name
        if folder.exists():
            for f in sorted(folder.iterdir()):
                if f.suffix.lower() in IMG_EXTS:
                    paths.append(str(f)); labels.append(val)
    return paths, labels

def make_ds(split_path, fn, shuffle=False):
    paths, labels = collect(split_path)
    ds = tf.data.Dataset.from_tensor_slices(
        (tf.constant(paths), tf.constant(labels, dtype=tf.int32)))
    if shuffle:
        ds = ds.shuffle(len(paths), seed=RANDOM_SEED, reshuffle_each_iteration=True)
    return (ds.map(fn, num_parallel_calls=tf.data.AUTOTUNE)
              .batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE),
            len(paths), paths, labels)

train_ds, n_train, train_paths, train_labels = make_ds(TRAIN_DIR, preprocess_train, True)
val_ds,   n_val,   _,           val_labels   = make_ds(VAL_DIR,   preprocess_val)
test_ds,  n_test,  _,           test_labels  = make_ds(TEST_DIR,  preprocess_val)
steps_per_epoch = math.ceil(n_train / BATCH_SIZE)
print(f"  Train:{n_train:,}  Val:{n_val:,}  Test:{n_test:,}  Steps/ep:{steps_per_epoch}")


# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# CELL 6 ── Build ResNet50 model
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━

print(f"\n▶  Building {MODEL_NAME} …\n")

base = ResNet50(weights="imagenet", include_top=False,
                input_shape=(IMG_SIZE, IMG_SIZE, CHANNELS))
base.trainable = False

x   = base.output
x   = layers.GlobalAveragePooling2D(name="gap")(x)
x   = layers.BatchNormalization(name="bn1")(x)
x   = layers.Dense(512, activation="relu",
                   kernel_regularizer=regularizers.l2(L2_REG), name="fc1")(x)
x   = layers.Dropout(DROPOUT_RATE, name="drop1")(x)
x   = layers.BatchNormalization(name="bn2")(x)
x   = layers.Dense(256, activation="relu",
                   kernel_regularizer=regularizers.l2(L2_REG), name="fc2")(x)
x   = layers.Dropout(0.3, name="drop2")(x)
out = layers.Dense(1, activation="sigmoid", dtype="float32", name="output")(x)

model = Model(base.input, out, name="ResNet50_BreastCancer")
model.summary(line_length=80)
print(f"  Trainable params : {sum(tf.size(w).numpy() for w in model.trainable_weights):,}")


# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# CELL 7 ── Cosine LR schedule
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━

def cosine_schedule(init_lr, total_epochs, steps_ep, warmup_ep=2, min_lr=1e-7):
    cosine = tf.keras.optimizers.schedules.CosineDecayRestarts(
        initial_learning_rate=init_lr,
        first_decay_steps=max((total_epochs - warmup_ep) * steps_ep // 3, 1),
        t_mul=2.0, m_mul=0.9, alpha=min_lr/init_lr)
    warmup_steps = warmup_ep * steps_ep
    class Schedule(tf.keras.optimizers.schedules.LearningRateSchedule):
        def __call__(self, step):
            step = tf.cast(step, tf.float32)
            return tf.where(step < warmup_steps,
                            init_lr * (step / max(warmup_steps, 1)),
                            cosine(tf.maximum(step - warmup_steps, 0)))
        def get_config(self): return {}
    return Schedule()

METRICS = [
    "accuracy",
    tf.keras.metrics.AUC(name="auc",    curve="ROC"),
    tf.keras.metrics.AUC(name="pr_auc", curve="PR"),
    tf.keras.metrics.Precision(name="precision"),
    tf.keras.metrics.Recall(name="recall"),
]


# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# CELL 8 ── Phase 1: Train head (backbone frozen)
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━

print("\n▶  Phase 1: head only …\n")
phase1_ckpt = str(SAVE_DIR / "phase1_best.weights.h5")

model.compile(optimizer=optimizers.Adam(cosine_schedule(PHASE1_LR, PHASE1_EPOCHS, steps_per_epoch)),
              loss="binary_crossentropy", metrics=METRICS)

history_p1 = model.fit(
    train_ds, epochs=PHASE1_EPOCHS, validation_data=val_ds,
    class_weight=CLASS_WEIGHTS, verbose=1,
    callbacks=[
        callbacks.ModelCheckpoint(phase1_ckpt, monitor="val_auc", mode="max",
                                  save_best_only=True, save_weights_only=True, verbose=1),
        callbacks.EarlyStopping(monitor="val_auc", patience=7, mode="max",
                                restore_best_weights=True, verbose=1),
        callbacks.TensorBoard(log_dir=str(SAVE_DIR/"logs"/"phase1")),
        callbacks.CSVLogger(str(SAVE_DIR/"phase1_history.csv")),
    ])
print(f"  ✔ Phase 1 done. Best val_AUC = {max(history_p1.history['val_auc']):.4f}")


# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# CELL 9 ── Phase 2: Fine-tune last 60 layers
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━

print(f"\n▶  Phase 2: fine-tune last {UNFREEZE_LAYERS} layers …\n")
phase2_ckpt = str(SAVE_DIR / "phase2_best.weights.h5")

backbone_layers = [l for l in model.layers if l.name not in CUSTOM_HEAD]
for l in backbone_layers: l.trainable = False
unfrozen = 0
for l in backbone_layers[-UNFREEZE_LAYERS:]:
    if not isinstance(l, layers.BatchNormalization):
        l.trainable = True; unfrozen += 1
print(f"  Unfrozen (non-BN): {unfrozen}")

model.compile(optimizer=optimizers.Adam(cosine_schedule(PHASE2_LR, PHASE2_EPOCHS,
                                                        steps_per_epoch, warmup_ep=3, min_lr=1e-8)),
              loss="binary_crossentropy", metrics=METRICS)

history_p2 = model.fit(
    train_ds, epochs=PHASE2_EPOCHS, validation_data=val_ds,
    class_weight=CLASS_WEIGHTS, verbose=1,
    callbacks=[
        callbacks.ModelCheckpoint(phase2_ckpt, monitor="val_auc", mode="max",
                                  save_best_only=True, save_weights_only=True, verbose=1),
        callbacks.EarlyStopping(monitor="val_auc", patience=10, mode="max",
                                restore_best_weights=True, verbose=1),
        callbacks.TensorBoard(log_dir=str(SAVE_DIR/"logs"/"phase2")),
        callbacks.CSVLogger(str(SAVE_DIR/"phase2_history.csv")),
    ])

model.save(str(SAVE_DIR / "resnet50_breast_cancer.keras"))
print(f"  ✔ Phase 2 done. Best val_AUC = {max(history_p2.history['val_auc']):.4f}")


# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# CELL 10 ── Evaluation
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━

print("\n▶  Test set evaluation …\n")
model.load_weights(phase2_ckpt)

y_prob = model.predict(test_ds, verbose=1).flatten()
y_true = np.array(test_labels)
y_pred = (y_prob >= 0.5).astype(int)

fpr_a, tpr_a, thr_a = roc_curve(y_true, y_prob)
opt_idx    = np.argmax(tpr_a - fpr_a)
opt_thresh = float(thr_a[opt_idx])
auc_roc    = roc_auc_score(y_true, y_prob)
ap         = average_precision_score(y_true, y_prob)
cm         = confusion_matrix(y_true, y_pred)
tn, fp, fn, tp = cm.ravel()

accuracy    = (tp+tn)/(tp+tn+fp+fn)
sensitivity = tp/(tp+fn)
specificity = tn/(tn+fp)
precision_v = tp/(tp+fp) if (tp+fp)>0 else 0
npv         = tn/(tn+fn) if (tn+fn)>0 else 0
f1          = f1_score(y_true, y_pred)
mcc         = matthews_corrcoef(y_true, y_pred)

print(f"  Accuracy:{accuracy:.4f}  AUC:{auc_roc:.4f}  F1:{f1:.4f}")
print(f"  Sensitivity:{sensitivity:.4f}  Specificity:{specificity:.4f}")
print(f"  TP={tp} TN={tn} FP={fp} FN={fn}  OptThr={opt_thresh:.4f}")
print()
print(classification_report(y_true, y_pred, target_names=["benign","malignant"]))

fig, axes = plt.subplots(1, 3, figsize=(18, 5))
fig.suptitle(f"{MODEL_NAME} — Test Set Evaluation", fontsize=13, fontweight="bold")
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", ax=axes[0],
            xticklabels=["Pred Benign","Pred Malignant"],
            yticklabels=["True Benign","True Malignant"], annot_kws={"size":14})
axes[0].set_title("Confusion Matrix (thr=0.50)")
axes[1].plot(fpr_a, tpr_a, "b-", lw=2, label=f"AUC={auc_roc:.4f}")
axes[1].plot([0,1],[0,1],"k--")
axes[1].scatter(fpr_a[opt_idx], tpr_a[opt_idx], color="red", s=80, label=f"Opt={opt_thresh:.2f}")
axes[1].set_xlabel("FPR"); axes[1].set_ylabel("TPR"); axes[1].set_title("ROC Curve")
axes[1].legend(); axes[1].grid(alpha=0.3)
pr_p, pr_r, _ = precision_recall_curve(y_true, y_prob)
axes[2].plot(pr_r, pr_p, "g-", lw=2, label=f"AP={ap:.4f}")
axes[2].axhline(y_true.mean(), color="r", ls="--")
axes[2].set_xlabel("Recall"); axes[2].set_ylabel("Precision"); axes[2].set_title("PR Curve")
axes[2].legend(); axes[2].grid(alpha=0.3)
plt.tight_layout()
plt.savefig(str(SAVE_DIR/"evaluation_plots.png"), dpi=150, bbox_inches="tight"); plt.show()

def plot_history(h1, h2, p1_end):
    def cat(k): return h1.history[k] + h2.history.get(k, [])
    fig, axes = plt.subplots(2, 3, figsize=(18, 10))
    fig.suptitle(f"{MODEL_NAME} Training History", fontsize=14, fontweight="bold")
    for ax, (tk, vk, title) in zip(axes.flat, [
        ("loss","val_loss","Loss"),("accuracy","val_accuracy","Accuracy"),
        ("auc","val_auc","ROC-AUC"),("pr_auc","val_pr_auc","PR-AUC"),
        ("precision","val_precision","Precision"),("recall","val_recall","Recall"),
    ]):
        ep = range(1, len(cat(tk))+1)
        ax.plot(ep, cat(tk), "b-o", ms=3, label="Train")
        ax.plot(ep, cat(vk), "r-o", ms=3, label="Val")
        ax.axvline(p1_end, color="gray", ls="--", alpha=0.7, label="Phase 2")
        ax.set_title(title); ax.legend(fontsize=8); ax.grid(alpha=0.3)
    plt.tight_layout()
    plt.savefig(str(SAVE_DIR/"training_history.png"), dpi=150, bbox_inches="tight"); plt.show()

plot_history(history_p1, history_p2, len(history_p1.history["loss"]))

results = {
    "model":"resnet50","img_size":IMG_SIZE,
    "accuracy":round(accuracy,4),"auc_roc":round(auc_roc,4),"pr_auc":round(ap,4),
    "f1":round(f1,4),"mcc":round(mcc,4),"sensitivity":round(sensitivity,4),
    "specificity":round(specificity,4),"precision":round(precision_v,4),"npv":round(npv,4),
    "opt_threshold":round(opt_thresh,4),
    "TP":int(tp),"TN":int(tn),"FP":int(fp),"FN":int(fn),"miss_rate":round(fn/(fn+tp),4),
}
pd.DataFrame([results]).to_csv(str(SAVE_DIR/"results_summary.csv"), index=False)
master_csv = str(SAVE_DIR.parent/"all_models_comparison.csv")
df = pd.read_csv(master_csv) if os.path.exists(master_csv) else pd.DataFrame()
df = df[df["model"] != "resnet50"] if len(df) else df
df = pd.concat([df, pd.DataFrame([results])], ignore_index=True)
df.to_csv(master_csv, index=False)
print(f"\n  ✅  ResNet50 complete!  AUC={auc_roc:.4f}  Sens={sensitivity:.4f}  F1={f1:.4f}")
# Out:
# ERROR: Could not find a version that satisfies the requirement tensorflow==2.15.0 (from versions: 2.16.0rc0, 2.16.1, 2.16.2, 2.17.0rc0, 2.17.0rc1, 2.17.0, 2.17.1, 2.18.0rc0, 2.18.0rc1, 2.18.0rc2, 2.18.0, 2.18.1, 2.19.0rc0, 2.19.0, 2.19.1, 2.20.0rc0, 2.20.0, 2.21.0rc0, 2.21.0rc1, 2.21.0)
# ERROR: No matching distribution found for tensorflow==2.15.0
# TensorFlow : 2.19.0
# GPU        : [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Policy     : mixed_float16
# Mounted at /content/drive
# =================================================================
#   Model      : ResNet50
#   Input size : 224×224×3
#   Save dir   : /content/drive/MyDrive/Breast_cancer_dataset/model_output/resnet50
# =================================================================
#   Split     Malignant   Benign   Total  Mal%
#   ──────────────────────────────────────────
#   train         1,004    1,472   2,476  40.5%
#   val             231      340     571  40.5%
#   test            215      287     502  42.8%
#
#   Class weights → benign:0.8410  malignant:1.2331
#   Train:2,476  Val:571  Test:502  Steps/ep:78
#
# ▶  Building ResNet50 …
#
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "ResNet50_BreastCancer"
# ┏━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)          ┃ Output Shape      ┃     Param # ┃ Connected to       ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer           │ (None, 224, 224,  │           0 │ -                  │
# │ (InputLayer)          │ 3)                │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv1_pad             │ (None, 230, 230,  │           0 │ input_layer[0][0]  │
# │ (ZeroPadding2D)       │ 3)                │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv1_conv (Conv2D)   │ (None, 112, 112,  │       9,472 │ conv1_pad[0][0]    │
# │                       │ 64)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv1_bn              │ (None, 112, 112,  │         256 │ conv1_conv[0][0]   │
# │ (BatchNormalization)  │ 64)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv1_relu            │ (None, 112, 112,  │           0 │ conv1_bn[0][0]     │
# │ (Activation)          │ 64)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ pool1_pad             │ (None, 114, 114,  │           0 │ conv1_relu[0][0]   │
# │ (ZeroPadding2D)       │ 64)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ pool1_pool            │ (None, 56, 56,    │           0 │ pool1_pad[0][0]    │
# │ (MaxPooling2D)        │ 64)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2_block1_1_conv   │ (None, 56, 56,    │       4,160 │ pool1_pool[0][0]   │
# │ (Conv2D)              │ 64)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2_block1_1_bn     │ (None, 56, 56,    │         256 │ conv2_block1_1_co… │
# │ (BatchNormalization)  │ 64)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2_block1_1_relu   │ (None, 56, 56,    │           0 │ conv2_block1_1_bn… │
# │ (Activation)          │ 64)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2_block1_2_conv   │ (None, 56, 56,    │      36,928 │ conv2_block1_1_re… │
# │ (Conv2D)              │ 64)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2_block1_2_bn     │ (None, 56, 56,    │         256 │ conv2_block1_2_co… │
# │ (BatchNormalization)  │ 64)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2_block1_2_relu   │ (None, 56, 56,    │           0 │ conv2_block1_2_bn… │
# │ (Activation)          │ 64)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2_block1_0_conv   │ (None, 56, 56,    │      16,640 │ pool1_pool[0][0]   │
# │ (Conv2D)              │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2_block1_3_conv   │ (None, 56, 56,    │      16,640 │ conv2_block1_2_re… │
# │ (Conv2D)              │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2_block1_0_bn     │ (None, 56, 56,    │       1,024 │ conv2_block1_0_co… │
# │ (BatchNormalization)  │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2_block1_3_bn     │ (None, 56, 56,    │       1,024 │ conv2_block1_3_co… │
# │ (BatchNormalization)  │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2_block1_add      │ (None, 56, 56,    │           0 │ conv2_block1_0_bn… │
# │ (Add)                 │ 256)              │             │ conv2_block1_3_bn… │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2_block1_out      │ (None, 56, 56,    │           0 │ conv2_block1_add[… │
# │ (Activation)          │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2_block2_1_conv   │ (None, 56, 56,    │      16,448 │ conv2_block1_out[… │
# │ (Conv2D)              │ 64)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2_block2_1_bn     │ (None, 56, 56,    │         256 │ conv2_block2_1_co… │
# │ (BatchNormalization)  │ 64)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2_block2_1_relu   │ (None, 56, 56,    │           0 │ conv2_block2_1_bn… │
# │ (Activation)          │ 64)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2_block2_2_conv   │ (None, 56, 56,    │      36,928 │ conv2_block2_1_re… │
# │ (Conv2D)              │ 64)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2_block2_2_bn     │ (None, 56, 56,    │         256 │ conv2_block2_2_co… │
# │ (BatchNormalization)  │ 64)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2_block2_2_relu   │ (None, 56, 56,    │           0 │ conv2_block2_2_bn… │
# │ (Activation)          │ 64)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2_block2_3_conv   │ (None, 56, 56,    │      16,640 │ conv2_block2_2_re… │
# │ (Conv2D)              │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2_block2_3_bn     │ (None, 56, 56,    │       1,024 │ conv2_block2_3_co… │
# │ (BatchNormalization)  │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2_block2_add      │ (None, 56, 56,    │           0 │ conv2_block1_out[… │
# │ (Add)                 │ 256)              │             │ conv2_block2_3_bn… │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2_block2_out      │ (None, 56, 56,    │           0 │ conv2_block2_add[… │
# │ (Activation)          │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2_block3_1_conv   │ (None, 56, 56,    │      16,448 │ conv2_block2_out[… │
# │ (Conv2D)              │ 64)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2_block3_1_bn     │ (None, 56, 56,    │         256 │ conv2_block3_1_co… │
# │ (BatchNormalization)  │ 64)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2_block3_1_relu   │ (None, 56, 56,    │           0 │ conv2_block3_1_bn… │
# │ (Activation)          │ 64)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2_block3_2_conv   │ (None, 56, 56,    │      36,928 │ conv2_block3_1_re… │
# │ (Conv2D)              │ 64)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2_block3_2_bn     │ (None, 56, 56,    │         256 │ conv2_block3_2_co… │
# │ (BatchNormalization)  │ 64)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2_block3_2_relu   │ (None, 56, 56,    │           0 │ conv2_block3_2_bn… │
# │ (Activation)          │ 64)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2_block3_3_conv   │ (None, 56, 56,    │      16,640 │ conv2_block3_2_re… │
# │ (Conv2D)              │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2_block3_3_bn     │ (None, 56, 56,    │       1,024 │ conv2_block3_3_co… │
# │ (BatchNormalization)  │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2_block3_add      │ (None, 56, 56,    │           0 │ conv2_block2_out[… │
# │ (Add)                 │ 256)              │             │ conv2_block3_3_bn… │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv2_block3_out      │ (None, 56, 56,    │           0 │ conv2_block3_add[… │
# │ (Activation)          │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block1_1_conv   │ (None, 28, 28,    │      32,896 │ conv2_block3_out[… │
# │ (Conv2D)              │ 128)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block1_1_bn     │ (None, 28, 28,    │         512 │ conv3_block1_1_co… │
# │ (BatchNormalization)  │ 128)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block1_1_relu   │ (None, 28, 28,    │           0 │ conv3_block1_1_bn… │
# │ (Activation)          │ 128)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block1_2_conv   │ (None, 28, 28,    │     147,584 │ conv3_block1_1_re… │
# │ (Conv2D)              │ 128)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block1_2_bn     │ (None, 28, 28,    │         512 │ conv3_block1_2_co… │
# │ (BatchNormalization)  │ 128)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block1_2_relu   │ (None, 28, 28,    │           0 │ conv3_block1_2_bn… │
# │ (Activation)          │ 128)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block1_0_conv   │ (None, 28, 28,    │     131,584 │ conv2_block3_out[… │
# │ (Conv2D)              │ 512)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block1_3_conv   │ (None, 28, 28,    │      66,048 │ conv3_block1_2_re… │
# │ (Conv2D)              │ 512)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block1_0_bn     │ (None, 28, 28,    │       2,048 │ conv3_block1_0_co… │
# │ (BatchNormalization)  │ 512)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block1_3_bn     │ (None, 28, 28,    │       2,048 │ conv3_block1_3_co… │
# │ (BatchNormalization)  │ 512)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block1_add      │ (None, 28, 28,    │           0 │ conv3_block1_0_bn… │
# │ (Add)                 │ 512)              │             │ conv3_block1_3_bn… │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block1_out      │ (None, 28, 28,    │           0 │ conv3_block1_add[… │
# │ (Activation)          │ 512)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block2_1_conv   │ (None, 28, 28,    │      65,664 │ conv3_block1_out[… │
# │ (Conv2D)              │ 128)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block2_1_bn     │ (None, 28, 28,    │         512 │ conv3_block2_1_co… │
# │ (BatchNormalization)  │ 128)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block2_1_relu   │ (None, 28, 28,    │           0 │ conv3_block2_1_bn… │
# │ (Activation)          │ 128)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block2_2_conv   │ (None, 28, 28,    │     147,584 │ conv3_block2_1_re… │
# │ (Conv2D)              │ 128)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block2_2_bn     │ (None, 28, 28,    │         512 │ conv3_block2_2_co… │
# │ (BatchNormalization)  │ 128)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block2_2_relu   │ (None, 28, 28,    │           0 │ conv3_block2_2_bn… │
# │ (Activation)          │ 128)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block2_3_conv   │ (None, 28, 28,    │      66,048 │ conv3_block2_2_re… │
# │ (Conv2D)              │ 512)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block2_3_bn     │ (None, 28, 28,    │       2,048 │ conv3_block2_3_co… │
# │ (BatchNormalization)  │ 512)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block2_add      │ (None, 28, 28,    │           0 │ conv3_block1_out[… │
# │ (Add)                 │ 512)              │             │ conv3_block2_3_bn… │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block2_out      │ (None, 28, 28,    │           0 │ conv3_block2_add[… │
# │ (Activation)          │ 512)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block3_1_conv   │ (None, 28, 28,    │      65,664 │ conv3_block2_out[… │
# │ (Conv2D)              │ 128)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block3_1_bn     │ (None, 28, 28,    │         512 │ conv3_block3_1_co… │
# │ (BatchNormalization)  │ 128)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block3_1_relu   │ (None, 28, 28,    │           0 │ conv3_block3_1_bn… │
# │ (Activation)          │ 128)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block3_2_conv   │ (None, 28, 28,    │     147,584 │ conv3_block3_1_re… │
# │ (Conv2D)              │ 128)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block3_2_bn     │ (None, 28, 28,    │         512 │ conv3_block3_2_co… │
# │ (BatchNormalization)  │ 128)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block3_2_relu   │ (None, 28, 28,    │           0 │ conv3_block3_2_bn… │
# │ (Activation)          │ 128)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block3_3_conv   │ (None, 28, 28,    │      66,048 │ conv3_block3_2_re… │
# │ (Conv2D)              │ 512)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block3_3_bn     │ (None, 28, 28,    │       2,048 │ conv3_block3_3_co… │
# │ (BatchNormalization)  │ 512)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block3_add      │ (None, 28, 28,    │           0 │ conv3_block2_out[… │
# │ (Add)                 │ 512)              │             │ conv3_block3_3_bn… │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block3_out      │ (None, 28, 28,    │           0 │ conv3_block3_add[… │
# │ (Activation)          │ 512)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block4_1_conv   │ (None, 28, 28,    │      65,664 │ conv3_block3_out[… │
# │ (Conv2D)              │ 128)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block4_1_bn     │ (None, 28, 28,    │         512 │ conv3_block4_1_co… │
# │ (BatchNormalization)  │ 128)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block4_1_relu   │ (None, 28, 28,    │           0 │ conv3_block4_1_bn… │
# │ (Activation)          │ 128)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block4_2_conv   │ (None, 28, 28,    │     147,584 │ conv3_block4_1_re… │
# │ (Conv2D)              │ 128)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block4_2_bn     │ (None, 28, 28,    │         512 │ conv3_block4_2_co… │
# │ (BatchNormalization)  │ 128)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block4_2_relu   │ (None, 28, 28,    │           0 │ conv3_block4_2_bn… │
# │ (Activation)          │ 128)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block4_3_conv   │ (None, 28, 28,    │      66,048 │ conv3_block4_2_re… │
# │ (Conv2D)              │ 512)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block4_3_bn     │ (None, 28, 28,    │       2,048 │ conv3_block4_3_co… │
# │ (BatchNormalization)  │ 512)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block4_add      │ (None, 28, 28,    │           0 │ conv3_block3_out[… │
# │ (Add)                 │ 512)              │             │ conv3_block4_3_bn… │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv3_block4_out      │ (None, 28, 28,    │           0 │ conv3_block4_add[… │
# │ (Activation)          │ 512)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block1_1_conv   │ (None, 14, 14,    │     131,328 │ conv3_block4_out[… │
# │ (Conv2D)              │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block1_1_bn     │ (None, 14, 14,    │       1,024 │ conv4_block1_1_co… │
# │ (BatchNormalization)  │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block1_1_relu   │ (None, 14, 14,    │           0 │ conv4_block1_1_bn… │
# │ (Activation)          │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block1_2_conv   │ (None, 14, 14,    │     590,080 │ conv4_block1_1_re… │
# │ (Conv2D)              │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block1_2_bn     │ (None, 14, 14,    │       1,024 │ conv4_block1_2_co… │
# │ (BatchNormalization)  │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block1_2_relu   │ (None, 14, 14,    │           0 │ conv4_block1_2_bn… │
# │ (Activation)          │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block1_0_conv   │ (None, 14, 14,    │     525,312 │ conv3_block4_out[… │
# │ (Conv2D)              │ 1024)             │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block1_3_conv   │ (None, 14, 14,    │     263,168 │ conv4_block1_2_re… │
# │ (Conv2D)              │ 1024)             │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block1_0_bn     │ (None, 14, 14,    │       4,096 │ conv4_block1_0_co… │
# │ (BatchNormalization)  │ 1024)             │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block1_3_bn     │ (None, 14, 14,    │       4,096 │ conv4_block1_3_co… │
# │ (BatchNormalization)  │ 1024)             │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block1_add      │ (None, 14, 14,    │           0 │ conv4_block1_0_bn… │
# │ (Add)                 │ 1024)             │             │ conv4_block1_3_bn… │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block1_out      │ (None, 14, 14,    │           0 │ conv4_block1_add[… │
# │ (Activation)          │ 1024)             │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block2_1_conv   │ (None, 14, 14,    │     262,400 │ conv4_block1_out[… │
# │ (Conv2D)              │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block2_1_bn     │ (None, 14, 14,    │       1,024 │ conv4_block2_1_co… │
# │ (BatchNormalization)  │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block2_1_relu   │ (None, 14, 14,    │           0 │ conv4_block2_1_bn… │
# │ (Activation)          │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block2_2_conv   │ (None, 14, 14,    │     590,080 │ conv4_block2_1_re… │
# │ (Conv2D)              │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block2_2_bn     │ (None, 14, 14,    │       1,024 │ conv4_block2_2_co… │
# │ (BatchNormalization)  │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block2_2_relu   │ (None, 14, 14,    │           0 │ conv4_block2_2_bn… │
# │ (Activation)          │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block2_3_conv   │ (None, 14, 14,    │     263,168 │ conv4_block2_2_re… │
# │ (Conv2D)              │ 1024)             │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block2_3_bn     │ (None, 14, 14,    │       4,096 │ conv4_block2_3_co… │
# │ (BatchNormalization)  │ 1024)             │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block2_add      │ (None, 14, 14,    │           0 │ conv4_block1_out[… │
# │ (Add)                 │ 1024)             │             │ conv4_block2_3_bn… │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block2_out      │ (None, 14, 14,    │           0 │ conv4_block2_add[… │
# │ (Activation)          │ 1024)             │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block3_1_conv   │ (None, 14, 14,    │     262,400 │ conv4_block2_out[… │
# │ (Conv2D)              │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block3_1_bn     │ (None, 14, 14,    │       1,024 │ conv4_block3_1_co… │
# │ (BatchNormalization)  │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block3_1_relu   │ (None, 14, 14,    │           0 │ conv4_block3_1_bn… │
# │ (Activation)          │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block3_2_conv   │ (None, 14, 14,    │     590,080 │ conv4_block3_1_re… │
# │ (Conv2D)              │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block3_2_bn     │ (None, 14, 14,    │       1,024 │ conv4_block3_2_co… │
# │ (BatchNormalization)  │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block3_2_relu   │ (None, 14, 14,    │           0 │ conv4_block3_2_bn… │
# │ (Activation)          │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block3_3_conv   │ (None, 14, 14,    │     263,168 │ conv4_block3_2_re… │
# │ (Conv2D)              │ 1024)             │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block3_3_bn     │ (None, 14, 14,    │       4,096 │ conv4_block3_3_co… │
# │ (BatchNormalization)  │ 1024)             │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block3_add      │ (None, 14, 14,    │           0 │ conv4_block2_out[… │
# │ (Add)                 │ 1024)             │             │ conv4_block3_3_bn… │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block3_out      │ (None, 14, 14,    │           0 │ conv4_block3_add[… │
# │ (Activation)          │ 1024)             │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block4_1_conv   │ (None, 14, 14,    │     262,400 │ conv4_block3_out[… │
# │ (Conv2D)              │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block4_1_bn     │ (None, 14, 14,    │       1,024 │ conv4_block4_1_co… │
# │ (BatchNormalization)  │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block4_1_relu   │ (None, 14, 14,    │           0 │ conv4_block4_1_bn… │
# │ (Activation)          │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block4_2_conv   │ (None, 14, 14,    │     590,080 │ conv4_block4_1_re… │
# │ (Conv2D)              │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block4_2_bn     │ (None, 14, 14,    │       1,024 │ conv4_block4_2_co… │
# │ (BatchNormalization)  │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block4_2_relu   │ (None, 14, 14,    │           0 │ conv4_block4_2_bn… │
# │ (Activation)          │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block4_3_conv   │ (None, 14, 14,    │     263,168 │ conv4_block4_2_re… │
# │ (Conv2D)              │ 1024)             │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block4_3_bn     │ (None, 14, 14,    │       4,096 │ conv4_block4_3_co… │
# │ (BatchNormalization)  │ 1024)             │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block4_add      │ (None, 14, 14,    │           0 │ conv4_block3_out[… │
# │ (Add)                 │ 1024)             │             │ conv4_block4_3_bn… │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block4_out      │ (None, 14, 14,    │           0 │ conv4_block4_add[… │
# │ (Activation)          │ 1024)             │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block5_1_conv   │ (None, 14, 14,    │     262,400 │ conv4_block4_out[… │
# │ (Conv2D)              │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block5_1_bn     │ (None, 14, 14,    │       1,024 │ conv4_block5_1_co… │
# │ (BatchNormalization)  │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block5_1_relu   │ (None, 14, 14,    │           0 │ conv4_block5_1_bn… │
# │ (Activation)          │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block5_2_conv   │ (None, 14, 14,    │     590,080 │ conv4_block5_1_re… │
# │ (Conv2D)              │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block5_2_bn     │ (None, 14, 14,    │       1,024 │ conv4_block5_2_co… │
# │ (BatchNormalization)  │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block5_2_relu   │ (None, 14, 14,    │           0 │ conv4_block5_2_bn… │
# │ (Activation)          │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block5_3_conv   │ (None, 14, 14,    │     263,168 │ conv4_block5_2_re… │
# │ (Conv2D)              │ 1024)             │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block5_3_bn     │ (None, 14, 14,    │       4,096 │ conv4_block5_3_co… │
# │ (BatchNormalization)  │ 1024)             │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block5_add      │ (None, 14, 14,    │           0 │ conv4_block4_out[… │
# │ (Add)                 │ 1024)             │             │ conv4_block5_3_bn… │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block5_out      │ (None, 14, 14,    │           0 │ conv4_block5_add[… │
# │ (Activation)          │ 1024)             │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block6_1_conv   │ (None, 14, 14,    │     262,400 │ conv4_block5_out[… │
# │ (Conv2D)              │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block6_1_bn     │ (None, 14, 14,    │       1,024 │ conv4_block6_1_co… │
# │ (BatchNormalization)  │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block6_1_relu   │ (None, 14, 14,    │           0 │ conv4_block6_1_bn… │
# │ (Activation)          │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block6_2_conv   │ (None, 14, 14,    │     590,080 │ conv4_block6_1_re… │
# │ (Conv2D)              │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block6_2_bn     │ (None, 14, 14,    │       1,024 │ conv4_block6_2_co… │
# │ (BatchNormalization)  │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block6_2_relu   │ (None, 14, 14,    │           0 │ conv4_block6_2_bn… │
# │ (Activation)          │ 256)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block6_3_conv   │ (None, 14, 14,    │     263,168 │ conv4_block6_2_re… │
# │ (Conv2D)              │ 1024)             │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block6_3_bn     │ (None, 14, 14,    │       4,096 │ conv4_block6_3_co… │
# │ (BatchNormalization)  │ 1024)             │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block6_add      │ (None, 14, 14,    │           0 │ conv4_block5_out[… │
# │ (Add)                 │ 1024)             │             │ conv4_block6_3_bn… │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv4_block6_out      │ (None, 14, 14,    │           0 │ conv4_block6_add[… │
# │ (Activation)          │ 1024)             │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv5_block1_1_conv   │ (None, 7, 7, 512) │     524,800 │ conv4_block6_out[… │
# │ (Conv2D)              │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv5_block1_1_bn     │ (None, 7, 7, 512) │       2,048 │ conv5_block1_1_co… │
# │ (BatchNormalization)  │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv5_block1_1_relu   │ (None, 7, 7, 512) │           0 │ conv5_block1_1_bn… │
# │ (Activation)          │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv5_block1_2_conv   │ (None, 7, 7, 512) │   2,359,808 │ conv5_block1_1_re… │
# │ (Conv2D)              │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv5_block1_2_bn     │ (None, 7, 7, 512) │       2,048 │ conv5_block1_2_co… │
# │ (BatchNormalization)  │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv5_block1_2_relu   │ (None, 7, 7, 512) │           0 │ conv5_block1_2_bn… │
# │ (Activation)          │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv5_block1_0_conv   │ (None, 7, 7,      │   2,099,200 │ conv4_block6_out[… │
# │ (Conv2D)              │ 2048)             │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv5_block1_3_conv   │ (None, 7, 7,      │   1,050,624 │ conv5_block1_2_re… │
# │ (Conv2D)              │ 2048)             │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv5_block1_0_bn     │ (None, 7, 7,      │       8,192 │ conv5_block1_0_co… │
# │ (BatchNormalization)  │ 2048)             │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv5_block1_3_bn     │ (None, 7, 7,      │       8,192 │ conv5_block1_3_co… │
# │ (BatchNormalization)  │ 2048)             │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv5_block1_add      │ (None, 7, 7,      │           0 │ conv5_block1_0_bn… │
# │ (Add)                 │ 2048)             │             │ conv5_block1_3_bn… │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv5_block1_out      │ (None, 7, 7,      │           0 │ conv5_block1_add[… │
# │ (Activation)          │ 2048)             │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv5_block2_1_conv   │ (None, 7, 7, 512) │   1,049,088 │ conv5_block1_out[… │
# │ (Conv2D)              │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv5_block2_1_bn     │ (None, 7, 7, 512) │       2,048 │ conv5_block2_1_co… │
# │ (BatchNormalization)  │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv5_block2_1_relu   │ (None, 7, 7, 512) │           0 │ conv5_block2_1_bn… │
# │ (Activation)          │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv5_block2_2_conv   │ (None, 7, 7, 512) │   2,359,808 │ conv5_block2_1_re… │
# │ (Conv2D)              │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv5_block2_2_bn     │ (None, 7, 7, 512) │       2,048 │ conv5_block2_2_co… │
# │ (BatchNormalization)  │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv5_block2_2_relu   │ (None, 7, 7, 512) │           0 │ conv5_block2_2_bn… │
# │ (Activation)          │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv5_block2_3_conv   │ (None, 7, 7,      │   1,050,624 │ conv5_block2_2_re… │
# │ (Conv2D)              │ 2048)             │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv5_block2_3_bn     │ (None, 7, 7,      │       8,192 │ conv5_block2_3_co… │
# │ (BatchNormalization)  │ 2048)             │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv5_block2_add      │ (None, 7, 7,      │           0 │ conv5_block1_out[… │
# │ (Add)                 │ 2048)             │             │ conv5_block2_3_bn… │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv5_block2_out      │ (None, 7, 7,      │           0 │ conv5_block2_add[… │
# │ (Activation)          │ 2048)             │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv5_block3_1_conv   │ (None, 7, 7, 512) │   1,049,088 │ conv5_block2_out[… │
# │ (Conv2D)              │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv5_block3_1_bn     │ (None, 7, 7, 512) │       2,048 │ conv5_block3_1_co… │
# │ (BatchNormalization)  │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv5_block3_1_relu   │ (None, 7, 7, 512) │           0 │ conv5_block3_1_bn… │
# │ (Activation)          │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv5_block3_2_conv   │ (None, 7, 7, 512) │   2,359,808 │ conv5_block3_1_re… │
# │ (Conv2D)              │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv5_block3_2_bn     │ (None, 7, 7, 512) │       2,048 │ conv5_block3_2_co… │
# │ (BatchNormalization)  │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv5_block3_2_relu   │ (None, 7, 7, 512) │           0 │ conv5_block3_2_bn… │
# │ (Activation)          │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv5_block3_3_conv   │ (None, 7, 7,      │   1,050,624 │ conv5_block3_2_re… │
# │ (Conv2D)              │ 2048)             │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv5_block3_3_bn     │ (None, 7, 7,      │       8,192 │ conv5_block3_3_co… │
# │ (BatchNormalization)  │ 2048)             │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv5_block3_add      │ (None, 7, 7,      │           0 │ conv5_block2_out[… │
# │ (Add)                 │ 2048)             │             │ conv5_block3_3_bn… │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ conv5_block3_out      │ (None, 7, 7,      │           0 │ conv5_block3_add[… │
# │ (Activation)          │ 2048)             │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ gap                   │ (None, 2048)      │           0 │ conv5_block3_out[… │
# │ (GlobalAveragePoolin… │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ bn1                   │ (None, 2048)      │       8,192 │ gap[0][0]          │
# │ (BatchNormalization)  │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ fc1 (Dense)           │ (None, 512)       │   1,049,088 │ bn1[0][0]          │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ drop1 (Dropout)       │ (None, 512)       │           0 │ fc1[0][0]          │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ bn2                   │ (None, 512)       │       2,048 │ drop1[0][0]        │
# │ (BatchNormalization)  │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ fc2 (Dense)           │ (None, 256)       │     131,328 │ bn2[0][0]          │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ drop2 (Dropout)       │ (None, 256)       │           0 │ fc2[0][0]          │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ output (Dense)        │ (None, 1)         │         257 │ drop2[0][0]        │
# └───────────────────────┴───────────────────┴─────────────┴────────────────────┘
#  Total params: 24,778,625 (94.52 MB)
#  Trainable params: 1,185,793 (4.52 MB)
#  Non-trainable params: 23,592,832 (90.00 MB)
#   Trainable params : 1,185,793
#
# ▶  Phase 1: head only …
#
# Epoch 1/20
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.5559 - auc: 0.5611 - loss: 0.9223 - pr_auc: 0.4467 - precision: 0.4421 - recall: 0.4170
# Epoch 1: val_auc improved from -inf to 0.51776, saving model to /content/drive/MyDrive/Breast_cancer_dataset/model_output/resnet50/phase1_best.weights.h5
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 430s 5s/step - accuracy: 0.5560 - auc: 0.5614 - loss: 0.9220 - pr_auc: 0.4469 - precision: 0.4424 - recall: 0.4181 - val_accuracy: 0.5622 - val_auc: 0.5178 - val_loss: 0.8319 - val_pr_auc: 0.4214 - val_precision: 0.4174 - val_recall: 0.2078
# Epoch 2/20
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step - accuracy: 0.5917 - auc: 0.6418 - loss: 0.8300 - pr_auc: 0.5253 - precision: 0.5010 - recall: 0.6216
# Epoch 2: val_auc improved from 0.51776 to 0.58288, saving model to /content/drive/MyDrive/Breast_cancer_dataset/model_output/resnet50/phase1_best.weights.h5
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 39s 499ms/step - accuracy: 0.5918 - auc: 0.6418 - loss: 0.8300 - pr_auc: 0.5252 - precision: 0.5010 - recall: 0.6216 - val_accuracy: 0.5779 - val_auc: 0.5829 - val_loss: 0.8893 - val_pr_auc: 0.4549 - val_precision: 0.4479 - val_recall: 0.1861
# Epoch 3/20
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step - accuracy: 0.5911 - auc: 0.6386 - loss: 0.8593 - pr_auc: 0.5142 - precision: 0.5018 - recall: 0.6070
# Epoch 3: val_auc improved from 0.58288 to 0.58293, saving model to /content/drive/MyDrive/Breast_cancer_dataset/model_output/resnet50/phase1_best.weights.h5
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 40s 502ms/step - accuracy: 0.5911 - auc: 0.6385 - loss: 0.8593 - pr_auc: 0.5141 - precision: 0.5017 - recall: 0.6070 - val_accuracy: 0.5744 - val_auc: 0.5829 - val_loss: 1.0127 - val_pr_auc: 0.4360 - val_precision: 0.3846 - val_recall: 0.0866
# Epoch 4/20
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step - accuracy: 0.6131 - auc: 0.6697 - loss: 0.8025 - pr_auc: 0.5387 - precision: 0.5155 - recall: 0.6613
# Epoch 4: val_auc did not improve from 0.58293
# ...
# Epoch 17: val_auc did not improve from 0.62706
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 42s 536ms/step - accuracy: 0.6847 - auc: 0.7602 - loss: 0.6899 - pr_auc: 0.6821 - precision: 0.5940 - recall: 0.6967 - val_accuracy: 0.5902 - val_auc: 0.6236 - val_loss: 1.4175 - val_pr_auc: 0.5022 - val_precision: 0.4909 - val_recall: 0.3506
# Epoch 18/20
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step - accuracy: 0.7024 - auc: 0.7856 - loss: 0.6684 - pr_auc: 0.7045 - precision: 0.6112 - recall: 0.7574
# Epoch 18: val_auc did not improve from 0.62706
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 34s 438ms/step - accuracy: 0.7023 - auc: 0.7854 - loss: 0.6685 - pr_auc: 0.7043 - precision: 0.6110 - recall: 0.7572 - val_accuracy: 0.5937 - val_auc: 0.6260 - val_loss: 1.4751 - val_pr_auc: 0.5047 - val_precision: 0.4966 - val_recall: 0.3117
# Epoch 19/20
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step - accuracy: 0.6953 - auc: 0.7686 - loss: 0.6842 - pr_auc: 0.6915 - precision: 0.6090 - recall: 0.7216
# Epoch 19: val_auc did not improve from 0.62706
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 36s 459ms/step - accuracy: 0.6953 - auc: 0.7686 - loss: 0.6842 - pr_auc: 0.6912 - precision: 0.6089 - recall: 0.7218 - val_accuracy: 0.5884 - val_auc: 0.6242 - val_loss: 1.4702 - val_pr_auc: 0.5040 - val_precision: 0.4872 - val_recall: 0.3290
# Epoch 20/20
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step - accuracy: 0.7136 - auc: 0.7845 - loss: 0.6666 - pr_auc: 0.6824 - precision: 0.6117 - recall: 0.7610
# Epoch 20: val_auc did not improve from 0.62706
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 34s 438ms/step - accuracy: 0.7134 - auc: 0.7844 - loss: 0.6667 - pr_auc: 0.6824 - precision: 0.6116 - recall: 0.7608 - val_accuracy: 0.5849 - val_auc: 0.6243 - val_loss: 1.4595 - val_pr_auc: 0.5053 - val_precision: 0.4810 - val_recall: 0.3290
# Restoring model weights from the end of the best epoch: 16.
#   ✔ Phase 1 done. Best val_AUC = 0.6271
#
# ▶  Phase 2: fine-tune last 60 layers …
#
#   Unfrozen (non-BN): 42
# Epoch 1/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 577ms/step - accuracy: 0.6811 - auc: 0.6810 - loss: 0.6905 - pr_auc: 0.5697 - precision: 0.5619 - recall: 0.5605
# Epoch 1: val_auc improved from -inf to 0.62782, saving model to /content/drive/MyDrive/Breast_cancer_dataset/model_output/resnet50/phase2_best.weights.h5
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 92s 786ms/step - accuracy: 0.6811 - auc: 0.6814 - loss: 0.6905 - pr_auc: 0.5701 - precision: 0.5621 - recall: 0.5614 - val_accuracy: 0.5954 - val_auc: 0.6278 - val_loss: 1.3091 - val_pr_auc: 0.5022 - val_precision: 0.5000 - val_recall: 0.4719
# Epoch 2/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 420ms/step - accuracy: 0.6874 - auc: 0.7681 - loss: 0.6809 - pr_auc: 0.6766 - precision: 0.5855 - recall: 0.7338
# Epoch 2: val_auc did not improve from 0.62782
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 38s 480ms/step - accuracy: 0.6874 - auc: 0.7681 - loss: 0.6809 - pr_auc: 0.6767 - precision: 0.5856 - recall: 0.7337 - val_accuracy: 0.5849 - val_auc: 0.6205 - val_loss: 1.3846 - val_pr_auc: 0.4929 - val_precision: 0.4817 - val_recall: 0.3420
# Epoch 3/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 402ms/step - accuracy: 0.7024 - auc: 0.7684 - loss: 0.6865 - pr_auc: 0.6678 - precision: 0.5983 - recall: 0.7177
# Epoch 3: val_auc did not improve from 0.62782
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 45s 537ms/step - accuracy: 0.7023 - auc: 0.7684 - loss: 0.6866 - pr_auc: 0.6679 - precision: 0.5984 - recall: 0.7178 - val_accuracy: 0.6025 - val_auc: 0.6231 - val_loss: 1.4242 - val_pr_auc: 0.4979 - val_precision: 0.5112 - val_recall: 0.3939
# Epoch 4/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - accuracy: 0.6972 - auc: 0.7923 - loss: 0.6602 - pr_auc: 0.7048 - precision: 0.6098 - recall: 0.7339
# Epoch 4: val_auc improved from 0.62782 to 0.63744, saving model to /content/drive/MyDrive/Breast_cancer_dataset/model_output/resnet50/phase2_best.weights.h5
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 47s 598ms/step - accuracy: 0.6971 - auc: 0.7921 - loss: 0.6603 - pr_auc: 0.7046 - precision: 0.6097 - recall: 0.7337 - val_accuracy: 0.6130 - val_auc: 0.6374 - val_loss: 1.4243 - val_pr_auc: 0.5101 - val_precision: 0.5281 - val_recall: 0.4069
# Epoch 5/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 522ms/step - accuracy: 0.7213 - auc: 0.7965 - loss: 0.6552 - pr_auc: 0.7067 - precision: 0.6238 - recall: 0.7570
# Epoch 5: val_auc did not improve from 0.63744
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 47s 599ms/step - accuracy: 0.7211 - auc: 0.7964 - loss: 0.6554 - pr_auc: 0.7065 - precision: 0.6237 - recall: 0.7568 - val_accuracy: 0.6130 - val_auc: 0.6350 - val_loss: 1.6273 - val_pr_auc: 0.5092 - val_precision: 0.5357 - val_recall: 0.3247
# Epoch 6/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step - accuracy: 0.7019 - auc: 0.7845 - loss: 0.6666 - pr_auc: 0.7079 - precision: 0.6218 - recall: 0.7553
# Epoch 6: val_auc improved from 0.63744 to 0.63921, saving model to /content/drive/MyDrive/Breast_cancer_dataset/model_output/resnet50/phase2_best.weights.h5
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 47s 605ms/step - accuracy: 0.7019 - auc: 0.7844 - loss: 0.6666 - pr_auc: 0.7076 - precision: 0.6217 - recall: 0.7553 - val_accuracy: 0.6130 - val_auc: 0.6392 - val_loss: 1.5323 - val_pr_auc: 0.5048 - val_precision: 0.5321 - val_recall: 0.3593
# Epoch 7/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 526ms/step - accuracy: 0.7215 - auc: 0.8016 - loss: 0.6526 - pr_auc: 0.7180 - precision: 0.6245 - recall: 0.7711
# Epoch 7: val_auc improved from 0.63921 to 0.64564, saving model to /content/drive/MyDrive/Breast_cancer_dataset/model_output/resnet50/phase2_best.weights.h5
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 60s 769ms/step - accuracy: 0.7215 - auc: 0.8016 - loss: 0.6526 - pr_auc: 0.7180 - precision: 0.6246 - recall: 0.7711 - val_accuracy: 0.6130 - val_auc: 0.6456 - val_loss: 1.5120 - val_pr_auc: 0.5139 - val_precision: 0.5309 - val_recall: 0.3723
# Epoch 8/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step - accuracy: 0.7375 - auc: 0.8193 - loss: 0.6338 - pr_auc: 0.7398 - precision: 0.6497 - recall: 0.7637
# Epoch 8: val_auc improved from 0.64564 to 0.64598, saving model to /content/drive/MyDrive/Breast_cancer_dataset/model_output/resnet50/phase2_best.weights.h5
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 69s 599ms/step - accuracy: 0.7374 - auc: 0.8192 - loss: 0.6338 - pr_auc: 0.7397 - precision: 0.6495 - recall: 0.7636 - val_accuracy: 0.6200 - val_auc: 0.6460 - val_loss: 1.5063 - val_pr_auc: 0.5129 - val_precision: 0.5372 - val_recall: 0.4372
# Epoch 9/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 522ms/step - accuracy: 0.7286 - auc: 0.8175 - loss: 0.6296 - pr_auc: 0.7334 - precision: 0.6245 - recall: 0.7642
# Epoch 9: val_auc did not improve from 0.64598
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 46s 585ms/step - accuracy: 0.7287 - auc: 0.8175 - loss: 0.6296 - pr_auc: 0.7334 - precision: 0.6248 - recall: 0.7643 - val_accuracy: 0.6112 - val_auc: 0.6390 - val_loss: 1.6242 - val_pr_auc: 0.5115 - val_precision: 0.5287 - val_recall: 0.3593
# Epoch 10/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step - accuracy: 0.7396 - auc: 0.8314 - loss: 0.6197 - pr_auc: 0.7720 - precision: 0.6597 - recall: 0.7665
# Epoch 10: val_auc did not improve from 0.64598
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 37s 469ms/step - accuracy: 0.7395 - auc: 0.8313 - loss: 0.6198 - pr_auc: 0.7716 - precision: 0.6594 - recall: 0.7666 - val_accuracy: 0.6182 - val_auc: 0.6395 - val_loss: 1.6392 - val_pr_auc: 0.5087 - val_precision: 0.5489 - val_recall: 0.3160
# Epoch 11/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - accuracy: 0.7241 - auc: 0.8112 - loss: 0.6401 - pr_auc: 0.7132 - precision: 0.6258 - recall: 0.7578
# Epoch 11: val_auc did not improve from 0.64598
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 36s 463ms/step - accuracy: 0.7243 - auc: 0.8114 - loss: 0.6399 - pr_auc: 0.7135 - precision: 0.6261 - recall: 0.7580 - val_accuracy: 0.6200 - val_auc: 0.6406 - val_loss: 1.6287 - val_pr_auc: 0.5100 - val_precision: 0.5507 - val_recall: 0.3290
# Epoch 12/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 393ms/step - accuracy: 0.7263 - auc: 0.8194 - loss: 0.6305 - pr_auc: 0.7405 - precision: 0.6350 - recall: 0.7671
# Epoch 12: val_auc did not improve from 0.64598
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 40s 453ms/step - accuracy: 0.7264 - auc: 0.8195 - loss: 0.6303 - pr_auc: 0.7407 - precision: 0.6352 - recall: 0.7672 - val_accuracy: 0.6165 - val_auc: 0.6422 - val_loss: 1.5921 - val_pr_auc: 0.5122 - val_precision: 0.5423 - val_recall: 0.3333
# Epoch 13/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step - accuracy: 0.7118 - auc: 0.7972 - loss: 0.6581 - pr_auc: 0.7296 - precision: 0.6295 - recall: 0.7471
# Epoch 13: val_auc did not improve from 0.64598
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 37s 475ms/step - accuracy: 0.7118 - auc: 0.7973 - loss: 0.6580 - pr_auc: 0.7295 - precision: 0.6295 - recall: 0.7471 - val_accuracy: 0.6112 - val_auc: 0.6340 - val_loss: 1.5400 - val_pr_auc: 0.5003 - val_precision: 0.5315 - val_recall: 0.3290
# Epoch 14/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 393ms/step - accuracy: 0.7376 - auc: 0.8227 - loss: 0.6278 - pr_auc: 0.7519 - precision: 0.6528 - recall: 0.7735
# Epoch 14: val_auc did not improve from 0.64598
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 35s 454ms/step - accuracy: 0.7375 - auc: 0.8226 - loss: 0.6279 - pr_auc: 0.7516 - precision: 0.6526 - recall: 0.7734 - val_accuracy: 0.6060 - val_auc: 0.6228 - val_loss: 1.9429 - val_pr_auc: 0.4974 - val_precision: 0.5417 - val_recall: 0.1688
# Epoch 15/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step - accuracy: 0.7383 - auc: 0.8326 - loss: 0.6134 - pr_auc: 0.7460 - precision: 0.6298 - recall: 0.7763
# Epoch 15: val_auc did not improve from 0.64598
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 42s 536ms/step - accuracy: 0.7383 - auc: 0.8325 - loss: 0.6136 - pr_auc: 0.7460 - precision: 0.6299 - recall: 0.7762 - val_accuracy: 0.6200 - val_auc: 0.6427 - val_loss: 1.6484 - val_pr_auc: 0.5164 - val_precision: 0.5714 - val_recall: 0.2424
# Epoch 16/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - accuracy: 0.7463 - auc: 0.8222 - loss: 0.6281 - pr_auc: 0.7494 - precision: 0.6552 - recall: 0.7856
# Epoch 16: val_auc did not improve from 0.64598
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 37s 479ms/step - accuracy: 0.7462 - auc: 0.8222 - loss: 0.6281 - pr_auc: 0.7494 - precision: 0.6551 - recall: 0.7854 - val_accuracy: 0.6182 - val_auc: 0.6375 - val_loss: 1.7818 - val_pr_auc: 0.5106 - val_precision: 0.5586 - val_recall: 0.2684
# Epoch 17/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 395ms/step - accuracy: 0.7286 - auc: 0.8276 - loss: 0.6191 - pr_auc: 0.7468 - precision: 0.6394 - recall: 0.7647
# Epoch 17: val_auc improved from 0.64598 to 0.64813, saving model to /content/drive/MyDrive/Breast_cancer_dataset/model_output/resnet50/phase2_best.weights.h5
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 44s 571ms/step - accuracy: 0.7288 - auc: 0.8277 - loss: 0.6191 - pr_auc: 0.7468 - precision: 0.6395 - recall: 0.7648 - val_accuracy: 0.6270 - val_auc: 0.6481 - val_loss: 1.4469 - val_pr_auc: 0.5244 - val_precision: 0.5479 - val_recall: 0.4459
# Epoch 18/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 527ms/step - accuracy: 0.7623 - auc: 0.8485 - loss: 0.5947 - pr_auc: 0.7785 - precision: 0.6730 - recall: 0.8210
# Epoch 18: val_auc did not improve from 0.64813
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 46s 596ms/step - accuracy: 0.7622 - auc: 0.8484 - loss: 0.5948 - pr_auc: 0.7785 - precision: 0.6728 - recall: 0.8209 - val_accuracy: 0.6130 - val_auc: 0.6441 - val_loss: 1.6082 - val_pr_auc: 0.5225 - val_precision: 0.5329 - val_recall: 0.3506
# Epoch 19/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 393ms/step - accuracy: 0.7457 - auc: 0.8385 - loss: 0.6055 - pr_auc: 0.7639 - precision: 0.6527 - recall: 0.7922
# Epoch 19: val_auc did not improve from 0.64813
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 37s 474ms/step - accuracy: 0.7459 - auc: 0.8386 - loss: 0.6055 - pr_auc: 0.7639 - precision: 0.6529 - recall: 0.7923 - val_accuracy: 0.6252 - val_auc: 0.6396 - val_loss: 1.6693 - val_pr_auc: 0.5174 - val_precision: 0.5528 - val_recall: 0.3853
# Epoch 20/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 395ms/step - accuracy: 0.7818 - auc: 0.8662 - loss: 0.5735 - pr_auc: 0.8076 - precision: 0.6980 - recall: 0.8043
# Epoch 20: val_auc did not improve from 0.64813
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 36s 456ms/step - accuracy: 0.7816 - auc: 0.8661 - loss: 0.5736 - pr_auc: 0.8074 - precision: 0.6978 - recall: 0.8041 - val_accuracy: 0.6287 - val_auc: 0.6451 - val_loss: 1.7331 - val_pr_auc: 0.5259 - val_precision: 0.5748 - val_recall: 0.3160
# Epoch 21/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - accuracy: 0.7646 - auc: 0.8663 - loss: 0.5698 - pr_auc: 0.8101 - precision: 0.6773 - recall: 0.8053
# Epoch 21: val_auc did not improve from 0.64813
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 37s 481ms/step - accuracy: 0.7646 - auc: 0.8662 - loss: 0.5700 - pr_auc: 0.8100 - precision: 0.6773 - recall: 0.8052 - val_accuracy: 0.6217 - val_auc: 0.6437 - val_loss: 1.9561 - val_pr_auc: 0.5231 - val_precision: 0.5824 - val_recall: 0.2294
# Epoch 22/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step - accuracy: 0.7548 - auc: 0.8450 - loss: 0.5956 - pr_auc: 0.7628 - precision: 0.6523 - recall: 0.8109
# Epoch 22: val_auc did not improve from 0.64813
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 36s 463ms/step - accuracy: 0.7550 - auc: 0.8451 - loss: 0.5955 - pr_auc: 0.7631 - precision: 0.6526 - recall: 0.8109 - val_accuracy: 0.6200 - val_auc: 0.6332 - val_loss: 1.9970 - val_pr_auc: 0.5120 - val_precision: 0.5921 - val_recall: 0.1948
# Epoch 23/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - accuracy: 0.7849 - auc: 0.8713 - loss: 0.5704 - pr_auc: 0.8199 - precision: 0.7046 - recall: 0.8240
# Epoch 23: val_auc did not improve from 0.64813
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 41s 532ms/step - accuracy: 0.7849 - auc: 0.8712 - loss: 0.5704 - pr_auc: 0.8197 - precision: 0.7045 - recall: 0.8241 - val_accuracy: 0.5989 - val_auc: 0.6246 - val_loss: 2.0289 - val_pr_auc: 0.5023 - val_precision: 0.5132 - val_recall: 0.1688
# Epoch 24/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 395ms/step - accuracy: 0.7606 - auc: 0.8529 - loss: 0.5840 - pr_auc: 0.8066 - precision: 0.6826 - recall: 0.7917
# Epoch 24: val_auc did not improve from 0.64813
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 41s 529ms/step - accuracy: 0.7608 - auc: 0.8531 - loss: 0.5837 - pr_auc: 0.8067 - precision: 0.6828 - recall: 0.7920 - val_accuracy: 0.6042 - val_auc: 0.6302 - val_loss: 2.0968 - val_pr_auc: 0.5080 - val_precision: 0.5397 - val_recall: 0.1472
# Epoch 25/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step - accuracy: 0.7891 - auc: 0.8892 - loss: 0.5390 - pr_auc: 0.8390 - precision: 0.6910 - recall: 0.8482
# Epoch 25: val_auc did not improve from 0.64813
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 35s 455ms/step - accuracy: 0.7891 - auc: 0.8891 - loss: 0.5391 - pr_auc: 0.8388 - precision: 0.6911 - recall: 0.8481 - val_accuracy: 0.6025 - val_auc: 0.6256 - val_loss: 2.0713 - val_pr_auc: 0.5082 - val_precision: 0.5303 - val_recall: 0.1515
# Epoch 26/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 395ms/step - accuracy: 0.7875 - auc: 0.8742 - loss: 0.5579 - pr_auc: 0.8198 - precision: 0.7102 - recall: 0.8220
# Epoch 26: val_auc did not improve from 0.64813
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 42s 463ms/step - accuracy: 0.7876 - auc: 0.8743 - loss: 0.5578 - pr_auc: 0.8198 - precision: 0.7102 - recall: 0.8222 - val_accuracy: 0.6025 - val_auc: 0.6169 - val_loss: 2.1474 - val_pr_auc: 0.5010 - val_precision: 0.5345 - val_recall: 0.1342
# Epoch 27/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step - accuracy: 0.7834 - auc: 0.8789 - loss: 0.5522 - pr_auc: 0.8299 - precision: 0.7007 - recall: 0.8212
# Epoch 27: val_auc did not improve from 0.64813
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 40s 451ms/step - accuracy: 0.7835 - auc: 0.8790 - loss: 0.5521 - pr_auc: 0.8299 - precision: 0.7008 - recall: 0.8214 - val_accuracy: 0.6007 - val_auc: 0.6150 - val_loss: 2.0849 - val_pr_auc: 0.4982 - val_precision: 0.5224 - val_recall: 0.1515
# Epoch 27: early stopping
# Restoring model weights from the end of the best epoch: 17.
#   ✔ Phase 2 done. Best val_AUC = 0.6481
#
# ▶  Test set evaluation …
#
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 91s 5s/step
#   Accuracy:0.6036  AUC:0.6293  F1:0.4962
#   Sensitivity:0.4558  Specificity:0.7143
#   TP=98 TN=205 FP=82 FN=117  OptThr=0.5618
#
#               precision    recall  f1-score   support
#
#       benign       0.64      0.71      0.67       287
#    malignant       0.54      0.46      0.50       215
#
#     accuracy                           0.60       502
#    macro avg       0.59      0.59      0.58       502
# weighted avg       0.60      0.60      0.60       502
#   ✅  ResNet50 complete!  AUC=0.6293  Sens=0.4558  F1=0.4962
