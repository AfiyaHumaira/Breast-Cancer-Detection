# %%
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# CELL 1 ── Install & verify GPU
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━

# !pip install -q tensorflow==2.15.0 scikit-learn matplotlib seaborn opencv-python-headless

import tensorflow as tf
from tensorflow.keras import mixed_precision
mixed_precision.set_global_policy("mixed_float16")

print("TensorFlow :", tf.__version__)
print("GPU        :", tf.config.list_physical_devices("GPU"))
print("Policy     :", mixed_precision.global_policy().name)


# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# CELL 2 ── Mount Drive & Configuration
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
import os, math, warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
from pathlib import Path
from sklearn.metrics import (
    confusion_matrix, classification_report, roc_auc_score,
    roc_curve, f1_score, average_precision_score,
    precision_recall_curve, matthews_corrcoef
)
from tensorflow.keras import layers, Model, callbacks, optimizers, regularizers
from tensorflow.keras.applications import EfficientNetB2
from tensorflow.keras.applications.efficientnet import preprocess_input

warnings.filterwarnings("ignore")
tf.get_logger().setLevel("ERROR")

# ── Paths ─────────────────────────────────────────────────────────────────
SPLIT_DIR = Path("/content/drive/MyDrive/Breast_cancer_dataset/cropped_split")
SAVE_DIR  = Path("/content/drive/MyDrive/Breast_cancer_dataset/model_output/efficientnet_b2")
SAVE_DIR.mkdir(parents=True, exist_ok=True)

TRAIN_DIR = SPLIT_DIR / "train"
VAL_DIR   = SPLIT_DIR / "val"
TEST_DIR  = SPLIT_DIR / "test"

# ── Settings ───────────────────────────────────────────────────────────────
MODEL_NAME      = "EfficientNet-B2"
IMG_SIZE        = 260          # EfficientNet-B2 native resolution
CHANNELS        = 3
BATCH_SIZE      = 32
PHASE1_EPOCHS   = 20
PHASE2_EPOCHS   = 30
PHASE1_LR       = 1e-3
PHASE2_LR       = 1e-5
UNFREEZE_LAYERS = 60
DROPOUT_RATE    = 0.5
L2_REG          = 1e-4
RANDOM_SEED     = 42
CUSTOM_HEAD     = {"gap","bn1","fc1","drop1","bn2","fc2","drop2","output"}

tf.random.set_seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)

print("=" * 65)
print(f"  Model      : {MODEL_NAME}")
print(f"  Input size : {IMG_SIZE}×{IMG_SIZE}×{CHANNELS}  (native B2 resolution)")
print(f"  Save dir   : {SAVE_DIR}")
print("=" * 65)


# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# CELL 3 ── Dataset inspection & class weights
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━

IMG_EXTS = (".jpg", ".jpeg", ".png")
stats = {}
for split in ["train", "val", "test"]:
    counts = {}
    for label in ["malignant", "benign"]:
        p = SPLIT_DIR / split / label
        counts[label] = len([f for f in p.iterdir()
                             if f.suffix.lower() in IMG_EXTS]) if p.exists() else 0
    stats[split] = counts

print(f"  {'Split':<8} {'Malignant':>10} {'Benign':>8} {'Total':>7}  Mal%")
print(f"  {'─'*42}")
for split, cnt in stats.items():
    mal = cnt["malignant"]; ben = cnt["benign"]; tot = mal + ben
    print(f"  {split:<8} {mal:>10,} {ben:>8,} {tot:>7,}  {mal/tot*100:.1f}%")

n_mal = stats["train"]["malignant"]
n_ben = stats["train"]["benign"]
n_tot = n_mal + n_ben
CLASS_WEIGHTS = {0: n_tot/(2*n_ben), 1: n_tot/(2*n_mal)}
print(f"\n  Class weights → benign:{CLASS_WEIGHTS[0]:.4f}  malignant:{CLASS_WEIGHTS[1]:.4f}")


# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# CELL 4 ── Preprocessing & augmentation
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━

def apply_clahe(img_np):
    img_u8 = img_np.astype(np.uint8)
    lab     = cv2.cvtColor(img_u8, cv2.COLOR_RGB2LAB)
    l, a, b = cv2.split(lab)
    clahe   = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    lab_eq  = cv2.merge([clahe.apply(l), a, b])
    return cv2.cvtColor(lab_eq, cv2.COLOR_LAB2RGB)

def preprocess_train(image_path, label):
    raw   = tf.io.read_file(image_path)
    image = tf.image.decode_jpeg(raw, channels=CHANNELS)
    image = tf.image.resize(image, [IMG_SIZE, IMG_SIZE])
    image = tf.cast(image, tf.uint8)
    image = tf.py_function(lambda x: apply_clahe(x.numpy()), [image], tf.uint8)
    image.set_shape([IMG_SIZE, IMG_SIZE, 3])
    image = tf.cast(image, tf.float32)
    image = preprocess_input(image)
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_flip_up_down(image)
    crop_pct  = tf.random.uniform([], 0.85, 1.0)
    crop_size = tf.cast(tf.cast(IMG_SIZE, tf.float32) * crop_pct, tf.int32)
    image = tf.image.random_crop(image, [crop_size, crop_size, 3])
    image = tf.image.resize(image, [IMG_SIZE, IMG_SIZE])
    image = tf.image.random_brightness(image, max_delta=0.2)
    image = tf.image.random_contrast(image, lower=0.8, upper=1.2)
    noise = tf.random.normal(tf.shape(image), mean=0.0, stddev=0.02)
    image = tf.clip_by_value(image + noise, -3.0, 3.0)
    return image, tf.cast(label, tf.float32)

def preprocess_val(image_path, label):
    raw   = tf.io.read_file(image_path)
    image = tf.image.decode_jpeg(raw, channels=CHANNELS)
    image = tf.image.resize(image, [IMG_SIZE, IMG_SIZE])
    image = tf.cast(image, tf.uint8)
    image = tf.py_function(lambda x: apply_clahe(x.numpy()), [image], tf.uint8)
    image.set_shape([IMG_SIZE, IMG_SIZE, 3])
    image = tf.cast(image, tf.float32)
    image = preprocess_input(image)
    return image, tf.cast(label, tf.float32)


# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# CELL 5 ── tf.data pipelines
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━

def collect(split_path):
    paths, labels = [], []
    for name, val in [("malignant",1),("benign",0)]:
        folder = split_path / name
        if folder.exists():
            for f in sorted(folder.iterdir()):
                if f.suffix.lower() in IMG_EXTS:
                    paths.append(str(f)); labels.append(val)
    return paths, labels

def make_ds(split_path, fn, shuffle=False):
    paths, labels = collect(split_path)
    ds = tf.data.Dataset.from_tensor_slices(
        (tf.constant(paths), tf.constant(labels, dtype=tf.int32)))
    if shuffle:
        ds = ds.shuffle(len(paths), seed=RANDOM_SEED, reshuffle_each_iteration=True)
    return (ds.map(fn, num_parallel_calls=tf.data.AUTOTUNE)
              .batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE),
            len(paths), paths, labels)

train_ds, n_train, _, train_labels = make_ds(TRAIN_DIR, preprocess_train, True)
val_ds,   n_val,   _, val_labels   = make_ds(VAL_DIR,   preprocess_val)
test_ds,  n_test,  _, test_labels  = make_ds(TEST_DIR,  preprocess_val)
steps_per_epoch = math.ceil(n_train / BATCH_SIZE)
print(f"  Train:{n_train:,}  Val:{n_val:,}  Test:{n_test:,}  Steps/ep:{steps_per_epoch}")


# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# CELL 6 ── Build EfficientNet-B2 model
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━

print(f"\n▶  Building {MODEL_NAME} …\n")

base = EfficientNetB2(weights="imagenet", include_top=False,
                      input_shape=(IMG_SIZE, IMG_SIZE, CHANNELS))
base.trainable = False

x   = base.output
x   = layers.GlobalAveragePooling2D(name="gap")(x)
x   = layers.BatchNormalization(name="bn1")(x)
x   = layers.Dense(512, activation="relu",
                   kernel_regularizer=regularizers.l2(L2_REG), name="fc1")(x)
x   = layers.Dropout(DROPOUT_RATE, name="drop1")(x)
x   = layers.BatchNormalization(name="bn2")(x)
x   = layers.Dense(256, activation="relu",
                   kernel_regularizer=regularizers.l2(L2_REG), name="fc2")(x)
x   = layers.Dropout(0.3, name="drop2")(x)
out = layers.Dense(1, activation="sigmoid", dtype="float32", name="output")(x)

model = Model(base.input, out, name="EfficientNetB2_BreastCancer")
model.summary(line_length=80)
print(f"  Trainable params : {sum(tf.size(w).numpy() for w in model.trainable_weights):,}")


# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# CELL 7 ── Cosine LR schedule
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━

def cosine_schedule(init_lr, total_epochs, steps_ep, warmup_ep=2, min_lr=1e-7):
    cosine = tf.keras.optimizers.schedules.CosineDecayRestarts(
        initial_learning_rate=init_lr,
        first_decay_steps=max((total_epochs - warmup_ep) * steps_ep // 3, 1),
        t_mul=2.0, m_mul=0.9, alpha=min_lr/init_lr)
    warmup_steps = warmup_ep * steps_ep
    class Schedule(tf.keras.optimizers.schedules.LearningRateSchedule):
        def __call__(self, step):
            step = tf.cast(step, tf.float32)
            return tf.where(step < warmup_steps,
                            init_lr * (step / max(warmup_steps, 1)),
                            cosine(tf.maximum(step - warmup_steps, 0)))
        def get_config(self): return {}
    return Schedule()

METRICS = [
    "accuracy",
    tf.keras.metrics.AUC(name="auc",    curve="ROC"),
    tf.keras.metrics.AUC(name="pr_auc", curve="PR"),
    tf.keras.metrics.Precision(name="precision"),
    tf.keras.metrics.Recall(name="recall"),
]


# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# CELL 8 ── Phase 1: Train head (backbone frozen)
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━

print("\n▶  Phase 1: head only …\n")
phase1_ckpt = str(SAVE_DIR / "phase1_best.weights.h5")

model.compile(optimizer=optimizers.Adam(cosine_schedule(PHASE1_LR, PHASE1_EPOCHS, steps_per_epoch)),
              loss="binary_crossentropy", metrics=METRICS)

history_p1 = model.fit(
    train_ds, epochs=PHASE1_EPOCHS, validation_data=val_ds,
    class_weight=CLASS_WEIGHTS, verbose=1,
    callbacks=[
        callbacks.ModelCheckpoint(phase1_ckpt, monitor="val_auc", mode="max",
                                  save_best_only=True, save_weights_only=True, verbose=1),
        callbacks.EarlyStopping(monitor="val_auc", patience=7, mode="max",
                                restore_best_weights=True, verbose=1),
        callbacks.TensorBoard(log_dir=str(SAVE_DIR/"logs"/"phase1")),
        callbacks.CSVLogger(str(SAVE_DIR/"phase1_history.csv")),
    ])
print(f"  ✔ Phase 1 done. Best val_AUC = {max(history_p1.history['val_auc']):.4f}")


# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# CELL 9 ── Phase 2: Fine-tune last 60 layers
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━

print(f"\n▶  Phase 2: fine-tune last {UNFREEZE_LAYERS} layers …\n")
phase2_ckpt = str(SAVE_DIR / "phase2_best.weights.h5")

backbone_layers = [l for l in model.layers if l.name not in CUSTOM_HEAD]
for l in backbone_layers: l.trainable = False
unfrozen = 0
for l in backbone_layers[-UNFREEZE_LAYERS:]:
    if not isinstance(l, layers.BatchNormalization):
        l.trainable = True; unfrozen += 1
print(f"  Unfrozen (non-BN): {unfrozen}")

model.compile(optimizer=optimizers.Adam(cosine_schedule(PHASE2_LR, PHASE2_EPOCHS,
                                                        steps_per_epoch, warmup_ep=3, min_lr=1e-8)),
              loss="binary_crossentropy", metrics=METRICS)

history_p2 = model.fit(
    train_ds, epochs=PHASE2_EPOCHS, validation_data=val_ds,
    class_weight=CLASS_WEIGHTS, verbose=1,
    callbacks=[
        callbacks.ModelCheckpoint(phase2_ckpt, monitor="val_auc", mode="max",
                                  save_best_only=True, save_weights_only=True, verbose=1),
        callbacks.EarlyStopping(monitor="val_auc", patience=10, mode="max",
                                restore_best_weights=True, verbose=1),
        callbacks.TensorBoard(log_dir=str(SAVE_DIR/"logs"/"phase2")),
        callbacks.CSVLogger(str(SAVE_DIR/"phase2_history.csv")),
    ])

model.save(str(SAVE_DIR / "efficientnet_b2_breast_cancer.keras"))
print(f"  ✔ Phase 2 done. Best val_AUC = {max(history_p2.history['val_auc']):.4f}")


# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# CELL 10 ── Evaluation
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━

print("\n▶  Test set evaluation …\n")
model.load_weights(phase2_ckpt)

y_prob = model.predict(test_ds, verbose=1).flatten()
y_true = np.array(test_labels)
y_pred = (y_prob >= 0.5).astype(int)

fpr_a, tpr_a, thr_a = roc_curve(y_true, y_prob)
opt_idx    = np.argmax(tpr_a - fpr_a)
opt_thresh = float(thr_a[opt_idx])
auc_roc    = roc_auc_score(y_true, y_prob)
ap         = average_precision_score(y_true, y_prob)
cm         = confusion_matrix(y_true, y_pred)
tn, fp, fn, tp = cm.ravel()

accuracy    = (tp+tn)/(tp+tn+fp+fn)
sensitivity = tp/(tp+fn)
specificity = tn/(tn+fp)
precision_v = tp/(tp+fp) if (tp+fp)>0 else 0
npv         = tn/(tn+fn) if (tn+fn)>0 else 0
f1          = f1_score(y_true, y_pred)
mcc         = matthews_corrcoef(y_true, y_pred)

print(f"  Accuracy:{accuracy:.4f}  AUC:{auc_roc:.4f}  F1:{f1:.4f}")
print(f"  Sensitivity:{sensitivity:.4f}  Specificity:{specificity:.4f}")
print(f"  TP={tp} TN={tn} FP={fp} FN={fn}  OptThr={opt_thresh:.4f}")
print()
print(classification_report(y_true, y_pred, target_names=["benign","malignant"]))

fig, axes = plt.subplots(1, 3, figsize=(18, 5))
fig.suptitle(f"{MODEL_NAME} — Test Set Evaluation", fontsize=13, fontweight="bold")
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", ax=axes[0],
            xticklabels=["Pred Benign","Pred Malignant"],
            yticklabels=["True Benign","True Malignant"], annot_kws={"size":14})
axes[0].set_title("Confusion Matrix (thr=0.50)")
axes[1].plot(fpr_a, tpr_a, "b-", lw=2, label=f"AUC={auc_roc:.4f}")
axes[1].plot([0,1],[0,1],"k--")
axes[1].scatter(fpr_a[opt_idx], tpr_a[opt_idx], color="red", s=80, label=f"Opt={opt_thresh:.2f}")
axes[1].set_xlabel("FPR"); axes[1].set_ylabel("TPR"); axes[1].set_title("ROC Curve")
axes[1].legend(); axes[1].grid(alpha=0.3)
pr_p, pr_r, _ = precision_recall_curve(y_true, y_prob)
axes[2].plot(pr_r, pr_p, "g-", lw=2, label=f"AP={ap:.4f}")
axes[2].axhline(y_true.mean(), color="r", ls="--")
axes[2].set_xlabel("Recall"); axes[2].set_ylabel("Precision"); axes[2].set_title("PR Curve")
axes[2].legend(); axes[2].grid(alpha=0.3)
plt.tight_layout()
plt.savefig(str(SAVE_DIR/"evaluation_plots.png"), dpi=150, bbox_inches="tight"); plt.show()

def plot_history(h1, h2, p1_end):
    def cat(k): return h1.history[k] + h2.history.get(k, [])
    fig, axes = plt.subplots(2, 3, figsize=(18, 10))
    fig.suptitle(f"{MODEL_NAME} Training History", fontsize=14, fontweight="bold")
    for ax, (tk, vk, title) in zip(axes.flat, [
        ("loss","val_loss","Loss"),("accuracy","val_accuracy","Accuracy"),
        ("auc","val_auc","ROC-AUC"),("pr_auc","val_pr_auc","PR-AUC"),
        ("precision","val_precision","Precision"),("recall","val_recall","Recall"),
    ]):
        ep = range(1, len(cat(tk))+1)
        ax.plot(ep, cat(tk), "b-o", ms=3, label="Train")
        ax.plot(ep, cat(vk), "r-o", ms=3, label="Val")
        ax.axvline(p1_end, color="gray", ls="--", alpha=0.7, label="Phase 2")
        ax.set_title(title); ax.legend(fontsize=8); ax.grid(alpha=0.3)
    plt.tight_layout()
    plt.savefig(str(SAVE_DIR/"training_history.png"), dpi=150, bbox_inches="tight"); plt.show()

plot_history(history_p1, history_p2, len(history_p1.history["loss"]))

results = {
    "model":"efficientnet_b2","img_size":IMG_SIZE,
    "accuracy":round(accuracy,4),"auc_roc":round(auc_roc,4),"pr_auc":round(ap,4),
    "f1":round(f1,4),"mcc":round(mcc,4),"sensitivity":round(sensitivity,4),
    "specificity":round(specificity,4),"precision":round(precision_v,4),"npv":round(npv,4),
    "opt_threshold":round(opt_thresh,4),
    "TP":int(tp),"TN":int(tn),"FP":int(fp),"FN":int(fn),"miss_rate":round(fn/(fn+tp),4),
}
pd.DataFrame([results]).to_csv(str(SAVE_DIR/"results_summary.csv"), index=False)
master_csv = str(SAVE_DIR.parent/"all_models_comparison.csv")
df = pd.read_csv(master_csv) if os.path.exists(master_csv) else pd.DataFrame()
df = df[df["model"] != "efficientnet_b2"] if len(df) else df
df = pd.concat([df, pd.DataFrame([results])], ignore_index=True)
df.to_csv(master_csv, index=False)
print(f"\n  ✅  EfficientNet-B2 complete!  AUC={auc_roc:.4f}  Sens={sensitivity:.4f}  F1={f1:.4f}")
# Out:
# ERROR: Could not find a version that satisfies the requirement tensorflow==2.15.0 (from versions: 2.16.0rc0, 2.16.1, 2.16.2, 2.17.0rc0, 2.17.0rc1, 2.17.0, 2.17.1, 2.18.0rc0, 2.18.0rc1, 2.18.0rc2, 2.18.0, 2.18.1, 2.19.0rc0, 2.19.0, 2.19.1, 2.20.0rc0, 2.20.0, 2.21.0rc0, 2.21.0rc1, 2.21.0)
# ERROR: No matching distribution found for tensorflow==2.15.0
# TensorFlow : 2.19.0
# GPU        : [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Policy     : mixed_float16
# =================================================================
#   Model      : EfficientNet-B2
#   Input size : 260×260×3  (native B2 resolution)
#   Save dir   : /content/drive/MyDrive/Breast_cancer_dataset/model_output/efficientnet_b2
# =================================================================
#   Split     Malignant   Benign   Total  Mal%
#   ──────────────────────────────────────────
#   train         1,004    1,472   2,476  40.5%
#   val             231      340     571  40.5%
#   test            215      287     502  42.8%
#
#   Class weights → benign:0.8410  malignant:1.2331
#   Train:2,476  Val:571  Test:502  Steps/ep:78
#
# ▶  Building EfficientNet-B2 …
#
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb2_notop.h5
# 31790344/31790344 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "EfficientNetB2_BreastCancer"
# ┏━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)          ┃ Output Shape      ┃     Param # ┃ Connected to       ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer           │ (None, 260, 260,  │           0 │ -                  │
# │ (InputLayer)          │ 3)                │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ rescaling (Rescaling) │ (None, 260, 260,  │           0 │ input_layer[0][0]  │
# │                       │ 3)                │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ normalization         │ (None, 260, 260,  │           7 │ rescaling[0][0]    │
# │ (Normalization)       │ 3)                │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ rescaling_1           │ (None, 260, 260,  │           0 │ normalization[0][… │
# │ (Rescaling)           │ 3)                │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ stem_conv_pad         │ (None, 261, 261,  │           0 │ rescaling_1[0][0]  │
# │ (ZeroPadding2D)       │ 3)                │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ stem_conv (Conv2D)    │ (None, 130, 130,  │         864 │ stem_conv_pad[0][… │
# │                       │ 32)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ stem_bn               │ (None, 130, 130,  │         128 │ stem_conv[0][0]    │
# │ (BatchNormalization)  │ 32)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ stem_activation       │ (None, 130, 130,  │           0 │ stem_bn[0][0]      │
# │ (Activation)          │ 32)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block1a_dwconv        │ (None, 130, 130,  │         288 │ stem_activation[0… │
# │ (DepthwiseConv2D)     │ 32)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block1a_bn            │ (None, 130, 130,  │         128 │ block1a_dwconv[0]… │
# │ (BatchNormalization)  │ 32)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block1a_activation    │ (None, 130, 130,  │           0 │ block1a_bn[0][0]   │
# │ (Activation)          │ 32)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block1a_se_squeeze    │ (None, 32)        │           0 │ block1a_activatio… │
# │ (GlobalAveragePoolin… │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block1a_se_reshape    │ (None, 1, 1, 32)  │           0 │ block1a_se_squeez… │
# │ (Reshape)             │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block1a_se_reduce     │ (None, 1, 1, 8)   │         264 │ block1a_se_reshap… │
# │ (Conv2D)              │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block1a_se_expand     │ (None, 1, 1, 32)  │         288 │ block1a_se_reduce… │
# │ (Conv2D)              │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block1a_se_excite     │ (None, 130, 130,  │           0 │ block1a_activatio… │
# │ (Multiply)            │ 32)               │             │ block1a_se_expand… │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block1a_project_conv  │ (None, 130, 130,  │         512 │ block1a_se_excite… │
# │ (Conv2D)              │ 16)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block1a_project_bn    │ (None, 130, 130,  │          64 │ block1a_project_c… │
# │ (BatchNormalization)  │ 16)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block1b_dwconv        │ (None, 130, 130,  │         144 │ block1a_project_b… │
# │ (DepthwiseConv2D)     │ 16)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block1b_bn            │ (None, 130, 130,  │          64 │ block1b_dwconv[0]… │
# │ (BatchNormalization)  │ 16)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block1b_activation    │ (None, 130, 130,  │           0 │ block1b_bn[0][0]   │
# │ (Activation)          │ 16)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block1b_se_squeeze    │ (None, 16)        │           0 │ block1b_activatio… │
# │ (GlobalAveragePoolin… │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block1b_se_reshape    │ (None, 1, 1, 16)  │           0 │ block1b_se_squeez… │
# │ (Reshape)             │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block1b_se_reduce     │ (None, 1, 1, 4)   │          68 │ block1b_se_reshap… │
# │ (Conv2D)              │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block1b_se_expand     │ (None, 1, 1, 16)  │          80 │ block1b_se_reduce… │
# │ (Conv2D)              │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block1b_se_excite     │ (None, 130, 130,  │           0 │ block1b_activatio… │
# │ (Multiply)            │ 16)               │             │ block1b_se_expand… │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block1b_project_conv  │ (None, 130, 130,  │         256 │ block1b_se_excite… │
# │ (Conv2D)              │ 16)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block1b_project_bn    │ (None, 130, 130,  │          64 │ block1b_project_c… │
# │ (BatchNormalization)  │ 16)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block1b_drop          │ (None, 130, 130,  │           0 │ block1b_project_b… │
# │ (Dropout)             │ 16)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block1b_add (Add)     │ (None, 130, 130,  │           0 │ block1b_drop[0][0… │
# │                       │ 16)               │             │ block1a_project_b… │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block2a_expand_conv   │ (None, 130, 130,  │       1,536 │ block1b_add[0][0]  │
# │ (Conv2D)              │ 96)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block2a_expand_bn     │ (None, 130, 130,  │         384 │ block2a_expand_co… │
# │ (BatchNormalization)  │ 96)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block2a_expand_activ… │ (None, 130, 130,  │           0 │ block2a_expand_bn… │
# │ (Activation)          │ 96)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block2a_dwconv_pad    │ (None, 131, 131,  │           0 │ block2a_expand_ac… │
# │ (ZeroPadding2D)       │ 96)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block2a_dwconv        │ (None, 65, 65,    │         864 │ block2a_dwconv_pa… │
# │ (DepthwiseConv2D)     │ 96)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block2a_bn            │ (None, 65, 65,    │         384 │ block2a_dwconv[0]… │
# │ (BatchNormalization)  │ 96)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block2a_activation    │ (None, 65, 65,    │           0 │ block2a_bn[0][0]   │
# │ (Activation)          │ 96)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block2a_se_squeeze    │ (None, 96)        │           0 │ block2a_activatio… │
# │ (GlobalAveragePoolin… │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block2a_se_reshape    │ (None, 1, 1, 96)  │           0 │ block2a_se_squeez… │
# │ (Reshape)             │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block2a_se_reduce     │ (None, 1, 1, 4)   │         388 │ block2a_se_reshap… │
# │ (Conv2D)              │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block2a_se_expand     │ (None, 1, 1, 96)  │         480 │ block2a_se_reduce… │
# │ (Conv2D)              │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block2a_se_excite     │ (None, 65, 65,    │           0 │ block2a_activatio… │
# │ (Multiply)            │ 96)               │             │ block2a_se_expand… │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block2a_project_conv  │ (None, 65, 65,    │       2,304 │ block2a_se_excite… │
# │ (Conv2D)              │ 24)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block2a_project_bn    │ (None, 65, 65,    │          96 │ block2a_project_c… │
# │ (BatchNormalization)  │ 24)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block2b_expand_conv   │ (None, 65, 65,    │       3,456 │ block2a_project_b… │
# │ (Conv2D)              │ 144)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block2b_expand_bn     │ (None, 65, 65,    │         576 │ block2b_expand_co… │
# │ (BatchNormalization)  │ 144)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block2b_expand_activ… │ (None, 65, 65,    │           0 │ block2b_expand_bn… │
# │ (Activation)          │ 144)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block2b_dwconv        │ (None, 65, 65,    │       1,296 │ block2b_expand_ac… │
# │ (DepthwiseConv2D)     │ 144)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block2b_bn            │ (None, 65, 65,    │         576 │ block2b_dwconv[0]… │
# │ (BatchNormalization)  │ 144)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block2b_activation    │ (None, 65, 65,    │           0 │ block2b_bn[0][0]   │
# │ (Activation)          │ 144)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block2b_se_squeeze    │ (None, 144)       │           0 │ block2b_activatio… │
# │ (GlobalAveragePoolin… │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block2b_se_reshape    │ (None, 1, 1, 144) │           0 │ block2b_se_squeez… │
# │ (Reshape)             │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block2b_se_reduce     │ (None, 1, 1, 6)   │         870 │ block2b_se_reshap… │
# │ (Conv2D)              │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block2b_se_expand     │ (None, 1, 1, 144) │       1,008 │ block2b_se_reduce… │
# │ (Conv2D)              │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block2b_se_excite     │ (None, 65, 65,    │           0 │ block2b_activatio… │
# │ (Multiply)            │ 144)              │             │ block2b_se_expand… │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block2b_project_conv  │ (None, 65, 65,    │       3,456 │ block2b_se_excite… │
# │ (Conv2D)              │ 24)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block2b_project_bn    │ (None, 65, 65,    │          96 │ block2b_project_c… │
# │ (BatchNormalization)  │ 24)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block2b_drop          │ (None, 65, 65,    │           0 │ block2b_project_b… │
# │ (Dropout)             │ 24)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block2b_add (Add)     │ (None, 65, 65,    │           0 │ block2b_drop[0][0… │
# │                       │ 24)               │             │ block2a_project_b… │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block2c_expand_conv   │ (None, 65, 65,    │       3,456 │ block2b_add[0][0]  │
# │ (Conv2D)              │ 144)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block2c_expand_bn     │ (None, 65, 65,    │         576 │ block2c_expand_co… │
# │ (BatchNormalization)  │ 144)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block2c_expand_activ… │ (None, 65, 65,    │           0 │ block2c_expand_bn… │
# │ (Activation)          │ 144)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block2c_dwconv        │ (None, 65, 65,    │       1,296 │ block2c_expand_ac… │
# │ (DepthwiseConv2D)     │ 144)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block2c_bn            │ (None, 65, 65,    │         576 │ block2c_dwconv[0]… │
# │ (BatchNormalization)  │ 144)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block2c_activation    │ (None, 65, 65,    │           0 │ block2c_bn[0][0]   │
# │ (Activation)          │ 144)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block2c_se_squeeze    │ (None, 144)       │           0 │ block2c_activatio… │
# │ (GlobalAveragePoolin… │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block2c_se_reshape    │ (None, 1, 1, 144) │           0 │ block2c_se_squeez… │
# │ (Reshape)             │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block2c_se_reduce     │ (None, 1, 1, 6)   │         870 │ block2c_se_reshap… │
# │ (Conv2D)              │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block2c_se_expand     │ (None, 1, 1, 144) │       1,008 │ block2c_se_reduce… │
# │ (Conv2D)              │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block2c_se_excite     │ (None, 65, 65,    │           0 │ block2c_activatio… │
# │ (Multiply)            │ 144)              │             │ block2c_se_expand… │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block2c_project_conv  │ (None, 65, 65,    │       3,456 │ block2c_se_excite… │
# │ (Conv2D)              │ 24)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block2c_project_bn    │ (None, 65, 65,    │          96 │ block2c_project_c… │
# │ (BatchNormalization)  │ 24)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block2c_drop          │ (None, 65, 65,    │           0 │ block2c_project_b… │
# │ (Dropout)             │ 24)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block2c_add (Add)     │ (None, 65, 65,    │           0 │ block2c_drop[0][0… │
# │                       │ 24)               │             │ block2b_add[0][0]  │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block3a_expand_conv   │ (None, 65, 65,    │       3,456 │ block2c_add[0][0]  │
# │ (Conv2D)              │ 144)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block3a_expand_bn     │ (None, 65, 65,    │         576 │ block3a_expand_co… │
# │ (BatchNormalization)  │ 144)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block3a_expand_activ… │ (None, 65, 65,    │           0 │ block3a_expand_bn… │
# │ (Activation)          │ 144)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block3a_dwconv_pad    │ (None, 69, 69,    │           0 │ block3a_expand_ac… │
# │ (ZeroPadding2D)       │ 144)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block3a_dwconv        │ (None, 33, 33,    │       3,600 │ block3a_dwconv_pa… │
# │ (DepthwiseConv2D)     │ 144)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block3a_bn            │ (None, 33, 33,    │         576 │ block3a_dwconv[0]… │
# │ (BatchNormalization)  │ 144)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block3a_activation    │ (None, 33, 33,    │           0 │ block3a_bn[0][0]   │
# │ (Activation)          │ 144)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block3a_se_squeeze    │ (None, 144)       │           0 │ block3a_activatio… │
# │ (GlobalAveragePoolin… │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block3a_se_reshape    │ (None, 1, 1, 144) │           0 │ block3a_se_squeez… │
# │ (Reshape)             │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block3a_se_reduce     │ (None, 1, 1, 6)   │         870 │ block3a_se_reshap… │
# │ (Conv2D)              │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block3a_se_expand     │ (None, 1, 1, 144) │       1,008 │ block3a_se_reduce… │
# │ (Conv2D)              │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block3a_se_excite     │ (None, 33, 33,    │           0 │ block3a_activatio… │
# │ (Multiply)            │ 144)              │             │ block3a_se_expand… │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block3a_project_conv  │ (None, 33, 33,    │       6,912 │ block3a_se_excite… │
# │ (Conv2D)              │ 48)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block3a_project_bn    │ (None, 33, 33,    │         192 │ block3a_project_c… │
# │ (BatchNormalization)  │ 48)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block3b_expand_conv   │ (None, 33, 33,    │      13,824 │ block3a_project_b… │
# │ (Conv2D)              │ 288)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block3b_expand_bn     │ (None, 33, 33,    │       1,152 │ block3b_expand_co… │
# │ (BatchNormalization)  │ 288)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block3b_expand_activ… │ (None, 33, 33,    │           0 │ block3b_expand_bn… │
# │ (Activation)          │ 288)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block3b_dwconv        │ (None, 33, 33,    │       7,200 │ block3b_expand_ac… │
# │ (DepthwiseConv2D)     │ 288)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block3b_bn            │ (None, 33, 33,    │       1,152 │ block3b_dwconv[0]… │
# │ (BatchNormalization)  │ 288)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block3b_activation    │ (None, 33, 33,    │           0 │ block3b_bn[0][0]   │
# │ (Activation)          │ 288)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block3b_se_squeeze    │ (None, 288)       │           0 │ block3b_activatio… │
# │ (GlobalAveragePoolin… │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block3b_se_reshape    │ (None, 1, 1, 288) │           0 │ block3b_se_squeez… │
# │ (Reshape)             │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block3b_se_reduce     │ (None, 1, 1, 12)  │       3,468 │ block3b_se_reshap… │
# │ (Conv2D)              │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block3b_se_expand     │ (None, 1, 1, 288) │       3,744 │ block3b_se_reduce… │
# │ (Conv2D)              │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block3b_se_excite     │ (None, 33, 33,    │           0 │ block3b_activatio… │
# │ (Multiply)            │ 288)              │             │ block3b_se_expand… │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block3b_project_conv  │ (None, 33, 33,    │      13,824 │ block3b_se_excite… │
# │ (Conv2D)              │ 48)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block3b_project_bn    │ (None, 33, 33,    │         192 │ block3b_project_c… │
# │ (BatchNormalization)  │ 48)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block3b_drop          │ (None, 33, 33,    │           0 │ block3b_project_b… │
# │ (Dropout)             │ 48)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block3b_add (Add)     │ (None, 33, 33,    │           0 │ block3b_drop[0][0… │
# │                       │ 48)               │             │ block3a_project_b… │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block3c_expand_conv   │ (None, 33, 33,    │      13,824 │ block3b_add[0][0]  │
# │ (Conv2D)              │ 288)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block3c_expand_bn     │ (None, 33, 33,    │       1,152 │ block3c_expand_co… │
# │ (BatchNormalization)  │ 288)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block3c_expand_activ… │ (None, 33, 33,    │           0 │ block3c_expand_bn… │
# │ (Activation)          │ 288)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block3c_dwconv        │ (None, 33, 33,    │       7,200 │ block3c_expand_ac… │
# │ (DepthwiseConv2D)     │ 288)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block3c_bn            │ (None, 33, 33,    │       1,152 │ block3c_dwconv[0]… │
# │ (BatchNormalization)  │ 288)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block3c_activation    │ (None, 33, 33,    │           0 │ block3c_bn[0][0]   │
# │ (Activation)          │ 288)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block3c_se_squeeze    │ (None, 288)       │           0 │ block3c_activatio… │
# │ (GlobalAveragePoolin… │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block3c_se_reshape    │ (None, 1, 1, 288) │           0 │ block3c_se_squeez… │
# │ (Reshape)             │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block3c_se_reduce     │ (None, 1, 1, 12)  │       3,468 │ block3c_se_reshap… │
# │ (Conv2D)              │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block3c_se_expand     │ (None, 1, 1, 288) │       3,744 │ block3c_se_reduce… │
# │ (Conv2D)              │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block3c_se_excite     │ (None, 33, 33,    │           0 │ block3c_activatio… │
# │ (Multiply)            │ 288)              │             │ block3c_se_expand… │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block3c_project_conv  │ (None, 33, 33,    │      13,824 │ block3c_se_excite… │
# │ (Conv2D)              │ 48)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block3c_project_bn    │ (None, 33, 33,    │         192 │ block3c_project_c… │
# │ (BatchNormalization)  │ 48)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block3c_drop          │ (None, 33, 33,    │           0 │ block3c_project_b… │
# │ (Dropout)             │ 48)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block3c_add (Add)     │ (None, 33, 33,    │           0 │ block3c_drop[0][0… │
# │                       │ 48)               │             │ block3b_add[0][0]  │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block4a_expand_conv   │ (None, 33, 33,    │      13,824 │ block3c_add[0][0]  │
# │ (Conv2D)              │ 288)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block4a_expand_bn     │ (None, 33, 33,    │       1,152 │ block4a_expand_co… │
# │ (BatchNormalization)  │ 288)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block4a_expand_activ… │ (None, 33, 33,    │           0 │ block4a_expand_bn… │
# │ (Activation)          │ 288)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block4a_dwconv_pad    │ (None, 35, 35,    │           0 │ block4a_expand_ac… │
# │ (ZeroPadding2D)       │ 288)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block4a_dwconv        │ (None, 17, 17,    │       2,592 │ block4a_dwconv_pa… │
# │ (DepthwiseConv2D)     │ 288)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block4a_bn            │ (None, 17, 17,    │       1,152 │ block4a_dwconv[0]… │
# │ (BatchNormalization)  │ 288)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block4a_activation    │ (None, 17, 17,    │           0 │ block4a_bn[0][0]   │
# │ (Activation)          │ 288)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block4a_se_squeeze    │ (None, 288)       │           0 │ block4a_activatio… │
# │ (GlobalAveragePoolin… │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block4a_se_reshape    │ (None, 1, 1, 288) │           0 │ block4a_se_squeez… │
# │ (Reshape)             │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block4a_se_reduce     │ (None, 1, 1, 12)  │       3,468 │ block4a_se_reshap… │
# │ (Conv2D)              │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block4a_se_expand     │ (None, 1, 1, 288) │       3,744 │ block4a_se_reduce… │
# │ (Conv2D)              │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block4a_se_excite     │ (None, 17, 17,    │           0 │ block4a_activatio… │
# │ (Multiply)            │ 288)              │             │ block4a_se_expand… │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block4a_project_conv  │ (None, 17, 17,    │      25,344 │ block4a_se_excite… │
# │ (Conv2D)              │ 88)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block4a_project_bn    │ (None, 17, 17,    │         352 │ block4a_project_c… │
# │ (BatchNormalization)  │ 88)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block4b_expand_conv   │ (None, 17, 17,    │      46,464 │ block4a_project_b… │
# │ (Conv2D)              │ 528)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block4b_expand_bn     │ (None, 17, 17,    │       2,112 │ block4b_expand_co… │
# │ (BatchNormalization)  │ 528)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block4b_expand_activ… │ (None, 17, 17,    │           0 │ block4b_expand_bn… │
# │ (Activation)          │ 528)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block4b_dwconv        │ (None, 17, 17,    │       4,752 │ block4b_expand_ac… │
# │ (DepthwiseConv2D)     │ 528)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block4b_bn            │ (None, 17, 17,    │       2,112 │ block4b_dwconv[0]… │
# │ (BatchNormalization)  │ 528)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block4b_activation    │ (None, 17, 17,    │           0 │ block4b_bn[0][0]   │
# │ (Activation)          │ 528)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block4b_se_squeeze    │ (None, 528)       │           0 │ block4b_activatio… │
# │ (GlobalAveragePoolin… │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block4b_se_reshape    │ (None, 1, 1, 528) │           0 │ block4b_se_squeez… │
# │ (Reshape)             │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block4b_se_reduce     │ (None, 1, 1, 22)  │      11,638 │ block4b_se_reshap… │
# │ (Conv2D)              │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block4b_se_expand     │ (None, 1, 1, 528) │      12,144 │ block4b_se_reduce… │
# │ (Conv2D)              │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block4b_se_excite     │ (None, 17, 17,    │           0 │ block4b_activatio… │
# │ (Multiply)            │ 528)              │             │ block4b_se_expand… │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block4b_project_conv  │ (None, 17, 17,    │      46,464 │ block4b_se_excite… │
# │ (Conv2D)              │ 88)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block4b_project_bn    │ (None, 17, 17,    │         352 │ block4b_project_c… │
# │ (BatchNormalization)  │ 88)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block4b_drop          │ (None, 17, 17,    │           0 │ block4b_project_b… │
# │ (Dropout)             │ 88)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block4b_add (Add)     │ (None, 17, 17,    │           0 │ block4b_drop[0][0… │
# │                       │ 88)               │             │ block4a_project_b… │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block4c_expand_conv   │ (None, 17, 17,    │      46,464 │ block4b_add[0][0]  │
# │ (Conv2D)              │ 528)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block4c_expand_bn     │ (None, 17, 17,    │       2,112 │ block4c_expand_co… │
# │ (BatchNormalization)  │ 528)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block4c_expand_activ… │ (None, 17, 17,    │           0 │ block4c_expand_bn… │
# │ (Activation)          │ 528)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block4c_dwconv        │ (None, 17, 17,    │       4,752 │ block4c_expand_ac… │
# │ (DepthwiseConv2D)     │ 528)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block4c_bn            │ (None, 17, 17,    │       2,112 │ block4c_dwconv[0]… │
# │ (BatchNormalization)  │ 528)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block4c_activation    │ (None, 17, 17,    │           0 │ block4c_bn[0][0]   │
# │ (Activation)          │ 528)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block4c_se_squeeze    │ (None, 528)       │           0 │ block4c_activatio… │
# │ (GlobalAveragePoolin… │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block4c_se_reshape    │ (None, 1, 1, 528) │           0 │ block4c_se_squeez… │
# │ (Reshape)             │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block4c_se_reduce     │ (None, 1, 1, 22)  │      11,638 │ block4c_se_reshap… │
# │ (Conv2D)              │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block4c_se_expand     │ (None, 1, 1, 528) │      12,144 │ block4c_se_reduce… │
# │ (Conv2D)              │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block4c_se_excite     │ (None, 17, 17,    │           0 │ block4c_activatio… │
# │ (Multiply)            │ 528)              │             │ block4c_se_expand… │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block4c_project_conv  │ (None, 17, 17,    │      46,464 │ block4c_se_excite… │
# │ (Conv2D)              │ 88)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block4c_project_bn    │ (None, 17, 17,    │         352 │ block4c_project_c… │
# │ (BatchNormalization)  │ 88)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block4c_drop          │ (None, 17, 17,    │           0 │ block4c_project_b… │
# │ (Dropout)             │ 88)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block4c_add (Add)     │ (None, 17, 17,    │           0 │ block4c_drop[0][0… │
# │                       │ 88)               │             │ block4b_add[0][0]  │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block4d_expand_conv   │ (None, 17, 17,    │      46,464 │ block4c_add[0][0]  │
# │ (Conv2D)              │ 528)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block4d_expand_bn     │ (None, 17, 17,    │       2,112 │ block4d_expand_co… │
# │ (BatchNormalization)  │ 528)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block4d_expand_activ… │ (None, 17, 17,    │           0 │ block4d_expand_bn… │
# │ (Activation)          │ 528)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block4d_dwconv        │ (None, 17, 17,    │       4,752 │ block4d_expand_ac… │
# │ (DepthwiseConv2D)     │ 528)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block4d_bn            │ (None, 17, 17,    │       2,112 │ block4d_dwconv[0]… │
# │ (BatchNormalization)  │ 528)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block4d_activation    │ (None, 17, 17,    │           0 │ block4d_bn[0][0]   │
# │ (Activation)          │ 528)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block4d_se_squeeze    │ (None, 528)       │           0 │ block4d_activatio… │
# │ (GlobalAveragePoolin… │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block4d_se_reshape    │ (None, 1, 1, 528) │           0 │ block4d_se_squeez… │
# │ (Reshape)             │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block4d_se_reduce     │ (None, 1, 1, 22)  │      11,638 │ block4d_se_reshap… │
# │ (Conv2D)              │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block4d_se_expand     │ (None, 1, 1, 528) │      12,144 │ block4d_se_reduce… │
# │ (Conv2D)              │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block4d_se_excite     │ (None, 17, 17,    │           0 │ block4d_activatio… │
# │ (Multiply)            │ 528)              │             │ block4d_se_expand… │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block4d_project_conv  │ (None, 17, 17,    │      46,464 │ block4d_se_excite… │
# │ (Conv2D)              │ 88)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block4d_project_bn    │ (None, 17, 17,    │         352 │ block4d_project_c… │
# │ (BatchNormalization)  │ 88)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block4d_drop          │ (None, 17, 17,    │           0 │ block4d_project_b… │
# │ (Dropout)             │ 88)               │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block4d_add (Add)     │ (None, 17, 17,    │           0 │ block4d_drop[0][0… │
# │                       │ 88)               │             │ block4c_add[0][0]  │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block5a_expand_conv   │ (None, 17, 17,    │      46,464 │ block4d_add[0][0]  │
# │ (Conv2D)              │ 528)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block5a_expand_bn     │ (None, 17, 17,    │       2,112 │ block5a_expand_co… │
# │ (BatchNormalization)  │ 528)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block5a_expand_activ… │ (None, 17, 17,    │           0 │ block5a_expand_bn… │
# │ (Activation)          │ 528)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block5a_dwconv        │ (None, 17, 17,    │      13,200 │ block5a_expand_ac… │
# │ (DepthwiseConv2D)     │ 528)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block5a_bn            │ (None, 17, 17,    │       2,112 │ block5a_dwconv[0]… │
# │ (BatchNormalization)  │ 528)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block5a_activation    │ (None, 17, 17,    │           0 │ block5a_bn[0][0]   │
# │ (Activation)          │ 528)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block5a_se_squeeze    │ (None, 528)       │           0 │ block5a_activatio… │
# │ (GlobalAveragePoolin… │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block5a_se_reshape    │ (None, 1, 1, 528) │           0 │ block5a_se_squeez… │
# │ (Reshape)             │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block5a_se_reduce     │ (None, 1, 1, 22)  │      11,638 │ block5a_se_reshap… │
# │ (Conv2D)              │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block5a_se_expand     │ (None, 1, 1, 528) │      12,144 │ block5a_se_reduce… │
# │ (Conv2D)              │                   │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block5a_se_excite     │ (None, 17, 17,    │           0 │ block5a_activatio… │
# │ (Multiply)            │ 528)              │             │ block5a_se_expand… │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block5a_project_conv  │ (None, 17, 17,    │      63,360 │ block5a_se_excite… │
# │ (Conv2D)              │ 120)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block5a_project_bn    │ (None, 17, 17,    │         480 │ block5a_project_c… │
# │ (BatchNormalization)  │ 120)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# │ block5b_expand_conv   │ (None, 17, 17,    │      86,400 │ block5a_project_b… │
# │ (Conv2D)              │ 720)              │             │                    │
# ├───────────────────────┼───────────────────┼─────────────┼────────────────────┤
# ...
# Epoch 9: val_auc improved from 0.52396 to 0.52443, saving model to /content/drive/MyDrive/Breast_cancer_dataset/model_output/efficientnet_b2/phase1_best.weights.h5
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 42s 544ms/step - accuracy: 0.4992 - auc: 0.5006 - loss: 0.8544 - pr_auc: 0.4175 - precision: 0.4183 - recall: 0.5461 - val_accuracy: 0.5849 - val_auc: 0.5244 - val_loss: 0.8536 - val_pr_auc: 0.4147 - val_precision: 0.3636 - val_recall: 0.0346
# Epoch 10/20
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 439ms/step - accuracy: 0.4752 - auc: 0.4746 - loss: 0.8731 - pr_auc: 0.3875 - precision: 0.3811 - recall: 0.4802
# Epoch 10: val_auc did not improve from 0.52443
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 41s 526ms/step - accuracy: 0.4752 - auc: 0.4747 - loss: 0.8729 - pr_auc: 0.3876 - precision: 0.3812 - recall: 0.4802 - val_accuracy: 0.5902 - val_auc: 0.4794 - val_loss: 1.0372 - val_pr_auc: 0.3823 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/20
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 435ms/step - accuracy: 0.5055 - auc: 0.4928 - loss: 0.8503 - pr_auc: 0.3955 - precision: 0.3995 - recall: 0.4707
# Epoch 11: val_auc did not improve from 0.52443
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 39s 504ms/step - accuracy: 0.5054 - auc: 0.4928 - loss: 0.8503 - pr_auc: 0.3956 - precision: 0.3996 - recall: 0.4709 - val_accuracy: 0.5306 - val_auc: 0.4614 - val_loss: 0.8388 - val_pr_auc: 0.3657 - val_precision: 0.3303 - val_recall: 0.1558
# Epoch 12/20
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step - accuracy: 0.5007 - auc: 0.5029 - loss: 0.8321 - pr_auc: 0.4205 - precision: 0.3924 - recall: 0.4602
# Epoch 12: val_auc did not improve from 0.52443
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 40s 490ms/step - accuracy: 0.5007 - auc: 0.5029 - loss: 0.8321 - pr_auc: 0.4205 - precision: 0.3925 - recall: 0.4603 - val_accuracy: 0.4974 - val_auc: 0.4400 - val_loss: 0.8552 - val_pr_auc: 0.3753 - val_precision: 0.3391 - val_recall: 0.2554
# Epoch 13/20
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 448ms/step - accuracy: 0.4888 - auc: 0.4825 - loss: 0.8288 - pr_auc: 0.4048 - precision: 0.3999 - recall: 0.4836
# Epoch 13: val_auc did not improve from 0.52443
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 40s 515ms/step - accuracy: 0.4889 - auc: 0.4827 - loss: 0.8287 - pr_auc: 0.4049 - precision: 0.4000 - recall: 0.4837 - val_accuracy: 0.5954 - val_auc: 0.4443 - val_loss: 1.0137 - val_pr_auc: 0.3616 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 14/20
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 444ms/step - accuracy: 0.5306 - auc: 0.5190 - loss: 0.8069 - pr_auc: 0.4121 - precision: 0.4026 - recall: 0.4567
# Epoch 14: val_auc did not improve from 0.52443
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 45s 578ms/step - accuracy: 0.5302 - auc: 0.5188 - loss: 0.8070 - pr_auc: 0.4120 - precision: 0.4027 - recall: 0.4573 - val_accuracy: 0.4974 - val_auc: 0.4597 - val_loss: 0.8408 - val_pr_auc: 0.3955 - val_precision: 0.3641 - val_recall: 0.3247
# Epoch 15/20
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 448ms/step - accuracy: 0.5049 - auc: 0.5174 - loss: 0.8164 - pr_auc: 0.4353 - precision: 0.4341 - recall: 0.5641
# Epoch 15: val_auc did not improve from 0.52443
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 45s 582ms/step - accuracy: 0.5050 - auc: 0.5174 - loss: 0.8163 - pr_auc: 0.4351 - precision: 0.4339 - recall: 0.5636 - val_accuracy: 0.4431 - val_auc: 0.4499 - val_loss: 0.8797 - val_pr_auc: 0.3924 - val_precision: 0.3670 - val_recall: 0.5195
# Epoch 16/20
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step - accuracy: 0.5140 - auc: 0.5087 - loss: 0.8122 - pr_auc: 0.4502 - precision: 0.4193 - recall: 0.4732
# Epoch 16: val_auc did not improve from 0.52443
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 41s 523ms/step - accuracy: 0.5138 - auc: 0.5085 - loss: 0.8122 - pr_auc: 0.4498 - precision: 0.4191 - recall: 0.4734 - val_accuracy: 0.5289 - val_auc: 0.4547 - val_loss: 0.8394 - val_pr_auc: 0.3927 - val_precision: 0.3603 - val_recall: 0.2121
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 9.
#   ✔ Phase 1 done. Best val_AUC = 0.5244
#
# ▶  Phase 2: fine-tune last 60 layers …
#
#   Unfrozen (non-BN): 47
# Epoch 1/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4841 - auc: 0.4898 - loss: 0.8620 - pr_auc: 0.4069 - precision: 0.3938 - recall: 0.4220
# Epoch 1: val_auc improved from -inf to 0.52686, saving model to /content/drive/MyDrive/Breast_cancer_dataset/model_output/efficientnet_b2/phase2_best.weights.h5
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 275s 2s/step - accuracy: 0.4842 - auc: 0.4899 - loss: 0.8620 - pr_auc: 0.4069 - precision: 0.3938 - recall: 0.4228 - val_accuracy: 0.5849 - val_auc: 0.5269 - val_loss: 0.8672 - val_pr_auc: 0.4165 - val_precision: 0.3500 - val_recall: 0.0303
# Epoch 2/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 482ms/step - accuracy: 0.4994 - auc: 0.4798 - loss: 0.8814 - pr_auc: 0.4007 - precision: 0.4162 - recall: 0.5458
# Epoch 2: val_auc improved from 0.52686 to 0.53580, saving model to /content/drive/MyDrive/Breast_cancer_dataset/model_output/efficientnet_b2/phase2_best.weights.h5
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 48s 618ms/step - accuracy: 0.4993 - auc: 0.4799 - loss: 0.8813 - pr_auc: 0.4007 - precision: 0.4160 - recall: 0.5455 - val_accuracy: 0.5832 - val_auc: 0.5358 - val_loss: 0.8625 - val_pr_auc: 0.4237 - val_precision: 0.3333 - val_recall: 0.0303
# Epoch 3/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 523ms/step - accuracy: 0.5084 - auc: 0.5149 - loss: 0.8460 - pr_auc: 0.4223 - precision: 0.4210 - recall: 0.5192
# Epoch 3: val_auc improved from 0.53580 to 0.53648, saving model to /content/drive/MyDrive/Breast_cancer_dataset/model_output/efficientnet_b2/phase2_best.weights.h5
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 50s 638ms/step - accuracy: 0.5082 - auc: 0.5146 - loss: 0.8462 - pr_auc: 0.4220 - precision: 0.4207 - recall: 0.5190 - val_accuracy: 0.5867 - val_auc: 0.5365 - val_loss: 0.8875 - val_pr_auc: 0.4288 - val_precision: 0.3077 - val_recall: 0.0173
# Epoch 4/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step - accuracy: 0.5131 - auc: 0.5163 - loss: 0.8419 - pr_auc: 0.4111 - precision: 0.4101 - recall: 0.5189
# Epoch 4: val_auc did not improve from 0.53648
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 44s 561ms/step - accuracy: 0.5131 - auc: 0.5163 - loss: 0.8419 - pr_auc: 0.4112 - precision: 0.4102 - recall: 0.5189 - val_accuracy: 0.5884 - val_auc: 0.5350 - val_loss: 0.8680 - val_pr_auc: 0.4265 - val_precision: 0.4231 - val_recall: 0.0476
# Epoch 5/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 491ms/step - accuracy: 0.4943 - auc: 0.4931 - loss: 0.8526 - pr_auc: 0.4183 - precision: 0.4023 - recall: 0.4825
# Epoch 5: val_auc did not improve from 0.53648
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 44s 559ms/step - accuracy: 0.4943 - auc: 0.4932 - loss: 0.8525 - pr_auc: 0.4181 - precision: 0.4023 - recall: 0.4826 - val_accuracy: 0.5902 - val_auc: 0.5282 - val_loss: 0.8867 - val_pr_auc: 0.4242 - val_precision: 0.4400 - val_recall: 0.0476
# Epoch 6/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 489ms/step - accuracy: 0.5062 - auc: 0.5209 - loss: 0.8322 - pr_auc: 0.4225 - precision: 0.4050 - recall: 0.5137
# Epoch 6: val_auc did not improve from 0.53648
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 44s 557ms/step - accuracy: 0.5062 - auc: 0.5207 - loss: 0.8323 - pr_auc: 0.4224 - precision: 0.4051 - recall: 0.5137 - val_accuracy: 0.5884 - val_auc: 0.5256 - val_loss: 0.8750 - val_pr_auc: 0.4227 - val_precision: 0.4286 - val_recall: 0.0519
# Epoch 7/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 480ms/step - accuracy: 0.5210 - auc: 0.5159 - loss: 0.8375 - pr_auc: 0.4055 - precision: 0.4069 - recall: 0.5056
# Epoch 7: val_auc did not improve from 0.53648
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 42s 544ms/step - accuracy: 0.5208 - auc: 0.5158 - loss: 0.8376 - pr_auc: 0.4056 - precision: 0.4069 - recall: 0.5055 - val_accuracy: 0.5937 - val_auc: 0.5250 - val_loss: 0.8815 - val_pr_auc: 0.4244 - val_precision: 0.4839 - val_recall: 0.0649
# Epoch 8/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step - accuracy: 0.4990 - auc: 0.5101 - loss: 0.8392 - pr_auc: 0.4323 - precision: 0.4096 - recall: 0.4838
# Epoch 8: val_auc did not improve from 0.53648
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 47s 600ms/step - accuracy: 0.4988 - auc: 0.5098 - loss: 0.8393 - pr_auc: 0.4320 - precision: 0.4094 - recall: 0.4840 - val_accuracy: 0.5884 - val_auc: 0.5241 - val_loss: 0.8859 - val_pr_auc: 0.4274 - val_precision: 0.4231 - val_recall: 0.0476
# Epoch 9/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 474ms/step - accuracy: 0.5032 - auc: 0.5065 - loss: 0.8432 - pr_auc: 0.4112 - precision: 0.4019 - recall: 0.5046
# Epoch 9: val_auc did not improve from 0.53648
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 42s 540ms/step - accuracy: 0.5033 - auc: 0.5065 - loss: 0.8432 - pr_auc: 0.4113 - precision: 0.4021 - recall: 0.5047 - val_accuracy: 0.5937 - val_auc: 0.5272 - val_loss: 0.9004 - val_pr_auc: 0.4314 - val_precision: 0.4737 - val_recall: 0.0390
# Epoch 10/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 470ms/step - accuracy: 0.5148 - auc: 0.5123 - loss: 0.8404 - pr_auc: 0.4458 - precision: 0.4383 - recall: 0.5159
# Epoch 10: val_auc did not improve from 0.53648
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 82s 540ms/step - accuracy: 0.5146 - auc: 0.5122 - loss: 0.8404 - pr_auc: 0.4455 - precision: 0.4379 - recall: 0.5157 - val_accuracy: 0.5954 - val_auc: 0.5305 - val_loss: 0.9056 - val_pr_auc: 0.4300 - val_precision: 0.5000 - val_recall: 0.0390
# Epoch 11/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 455ms/step - accuracy: 0.4924 - auc: 0.5006 - loss: 0.8435 - pr_auc: 0.4085 - precision: 0.3973 - recall: 0.5061
# Epoch 11: val_auc did not improve from 0.53648
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 81s 534ms/step - accuracy: 0.4925 - auc: 0.5007 - loss: 0.8435 - pr_auc: 0.4085 - precision: 0.3975 - recall: 0.5061 - val_accuracy: 0.5954 - val_auc: 0.5289 - val_loss: 0.9008 - val_pr_auc: 0.4288 - val_precision: 0.5000 - val_recall: 0.0390
# Epoch 12/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step - accuracy: 0.5034 - auc: 0.5142 - loss: 0.8364 - pr_auc: 0.4292 - precision: 0.4089 - recall: 0.5066
# Epoch 12: val_auc did not improve from 0.53648
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 42s 540ms/step - accuracy: 0.5034 - auc: 0.5141 - loss: 0.8364 - pr_auc: 0.4290 - precision: 0.4088 - recall: 0.5064 - val_accuracy: 0.5919 - val_auc: 0.5340 - val_loss: 0.8912 - val_pr_auc: 0.4365 - val_precision: 0.4500 - val_recall: 0.0390
# Epoch 13/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 438ms/step - accuracy: 0.5255 - auc: 0.5306 - loss: 0.8219 - pr_auc: 0.4225 - precision: 0.4162 - recall: 0.5356
# Epoch 13: val_auc improved from 0.53648 to 0.53852, saving model to /content/drive/MyDrive/Breast_cancer_dataset/model_output/efficientnet_b2/phase2_best.weights.h5
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 43s 555ms/step - accuracy: 0.5254 - auc: 0.5305 - loss: 0.8220 - pr_auc: 0.4225 - precision: 0.4164 - recall: 0.5355 - val_accuracy: 0.5902 - val_auc: 0.5385 - val_loss: 0.8551 - val_pr_auc: 0.4331 - val_precision: 0.4595 - val_recall: 0.0736
# Epoch 14/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 468ms/step - accuracy: 0.5094 - auc: 0.4987 - loss: 0.8509 - pr_auc: 0.4216 - precision: 0.4227 - recall: 0.5107
# Epoch 14: val_auc did not improve from 0.53852
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 47s 603ms/step - accuracy: 0.5092 - auc: 0.4986 - loss: 0.8509 - pr_auc: 0.4214 - precision: 0.4224 - recall: 0.5104 - val_accuracy: 0.5849 - val_auc: 0.5306 - val_loss: 0.8789 - val_pr_auc: 0.4265 - val_precision: 0.4000 - val_recall: 0.0519
# Epoch 15/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 443ms/step - accuracy: 0.4945 - auc: 0.4905 - loss: 0.8495 - pr_auc: 0.3851 - precision: 0.3910 - recall: 0.4922
# Epoch 15: val_auc did not improve from 0.53852
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 41s 527ms/step - accuracy: 0.4945 - auc: 0.4906 - loss: 0.8495 - pr_auc: 0.3853 - precision: 0.3911 - recall: 0.4923 - val_accuracy: 0.5814 - val_auc: 0.5303 - val_loss: 0.8679 - val_pr_auc: 0.4262 - val_precision: 0.3667 - val_recall: 0.0476
# Epoch 16/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 434ms/step - accuracy: 0.5009 - auc: 0.5054 - loss: 0.8425 - pr_auc: 0.4147 - precision: 0.4052 - recall: 0.4860
# Epoch 16: val_auc did not improve from 0.53852
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 39s 497ms/step - accuracy: 0.5010 - auc: 0.5054 - loss: 0.8425 - pr_auc: 0.4147 - precision: 0.4053 - recall: 0.4862 - val_accuracy: 0.5867 - val_auc: 0.5251 - val_loss: 0.8881 - val_pr_auc: 0.4208 - val_precision: 0.3810 - val_recall: 0.0346
# Epoch 17/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 446ms/step - accuracy: 0.4964 - auc: 0.4986 - loss: 0.8477 - pr_auc: 0.4218 - precision: 0.4157 - recall: 0.5222
# Epoch 17: val_auc did not improve from 0.53852
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 40s 509ms/step - accuracy: 0.4964 - auc: 0.4986 - loss: 0.8476 - pr_auc: 0.4216 - precision: 0.4155 - recall: 0.5220 - val_accuracy: 0.5902 - val_auc: 0.5273 - val_loss: 0.8916 - val_pr_auc: 0.4217 - val_precision: 0.4118 - val_recall: 0.0303
# Epoch 18/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 438ms/step - accuracy: 0.5015 - auc: 0.4931 - loss: 0.8455 - pr_auc: 0.4021 - precision: 0.4079 - recall: 0.4728
# Epoch 18: val_auc did not improve from 0.53852
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 45s 573ms/step - accuracy: 0.5016 - auc: 0.4933 - loss: 0.8455 - pr_auc: 0.4022 - precision: 0.4079 - recall: 0.4728 - val_accuracy: 0.5902 - val_auc: 0.5250 - val_loss: 0.8989 - val_pr_auc: 0.4194 - val_precision: 0.4000 - val_recall: 0.0260
# Epoch 19/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step - accuracy: 0.5203 - auc: 0.5163 - loss: 0.8286 - pr_auc: 0.3971 - precision: 0.4037 - recall: 0.5080
# Epoch 19: val_auc did not improve from 0.53852
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 41s 524ms/step - accuracy: 0.5204 - auc: 0.5165 - loss: 0.8286 - pr_auc: 0.3975 - precision: 0.4041 - recall: 0.5080 - val_accuracy: 0.5884 - val_auc: 0.5277 - val_loss: 0.8926 - val_pr_auc: 0.4213 - val_precision: 0.3333 - val_recall: 0.0173
# Epoch 20/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 442ms/step - accuracy: 0.5248 - auc: 0.5366 - loss: 0.8210 - pr_auc: 0.4333 - precision: 0.4252 - recall: 0.5042
# Epoch 20: val_auc did not improve from 0.53852
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 40s 517ms/step - accuracy: 0.5247 - auc: 0.5364 - loss: 0.8212 - pr_auc: 0.4331 - precision: 0.4251 - recall: 0.5042 - val_accuracy: 0.5849 - val_auc: 0.5227 - val_loss: 0.9004 - val_pr_auc: 0.4188 - val_precision: 0.2857 - val_recall: 0.0173
# Epoch 21/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 442ms/step - accuracy: 0.4813 - auc: 0.4786 - loss: 0.8519 - pr_auc: 0.3849 - precision: 0.3884 - recall: 0.4771
# Epoch 21: val_auc did not improve from 0.53852
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 40s 505ms/step - accuracy: 0.4815 - auc: 0.4789 - loss: 0.8517 - pr_auc: 0.3851 - precision: 0.3885 - recall: 0.4773 - val_accuracy: 0.5884 - val_auc: 0.5225 - val_loss: 0.9067 - val_pr_auc: 0.4189 - val_precision: 0.3333 - val_recall: 0.0173
# Epoch 22/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step - accuracy: 0.5094 - auc: 0.5134 - loss: 0.8332 - pr_auc: 0.4287 - precision: 0.4198 - recall: 0.5057
# Epoch 22: val_auc did not improve from 0.53852
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 42s 521ms/step - accuracy: 0.5094 - auc: 0.5134 - loss: 0.8333 - pr_auc: 0.4285 - precision: 0.4197 - recall: 0.5056 - val_accuracy: 0.5919 - val_auc: 0.5188 - val_loss: 0.9291 - val_pr_auc: 0.4152 - val_precision: 0.4000 - val_recall: 0.0173
# Epoch 23/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 434ms/step - accuracy: 0.5285 - auc: 0.5305 - loss: 0.8276 - pr_auc: 0.4362 - precision: 0.4304 - recall: 0.5189
# Epoch 23: val_auc did not improve from 0.53852
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 40s 507ms/step - accuracy: 0.5284 - auc: 0.5304 - loss: 0.8276 - pr_auc: 0.4362 - precision: 0.4304 - recall: 0.5187 - val_accuracy: 0.5919 - val_auc: 0.5183 - val_loss: 0.9334 - val_pr_auc: 0.4158 - val_precision: 0.3750 - val_recall: 0.0130
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 13.
#   ✔ Phase 2 done. Best val_AUC = 0.5385
#
# ▶  Test set evaluation …
#
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 155s 8s/step
#   Accuracy:0.5438  AUC:0.4709  F1:0.1358
#   Sensitivity:0.0837  Specificity:0.8885
#   TP=18 TN=255 FP=32 FN=197  OptThr=0.1803
#
#               precision    recall  f1-score   support
#
#       benign       0.56      0.89      0.69       287
#    malignant       0.36      0.08      0.14       215
#
#     accuracy                           0.54       502
#    macro avg       0.46      0.49      0.41       502
# weighted avg       0.48      0.54      0.45       502
#   ✅  EfficientNet-B2 complete!  AUC=0.4709  Sens=0.0837  F1=0.1358
